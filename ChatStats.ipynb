# %%
# Read 'chats' from an input file.
chats = []
filepath = "/Users/vaibhavtripathi/Downloads/WhatsApp_Chat.txt"
with open(filepath, 'r') as f:
    for line in f:
        chats.append(line.strip('\n '))

# %%
def is_valid(line):
    if ': ' in line and ' - ' in line:
        return True
    return False

# Handle multiline chats.
modified_chats = []
for chat in chats:
    if is_valid(chat):
        modified_chats.append(chat)
    else:
        # If line is not a new chat, add it to an earlier chat line. 
        modified_chats[-1] += " "
        modified_chats[-1] += chat
        
chats = modified_chats

# %%
# Convert chat strings into tuple (<date>,<time>,<speaker>,<speech>)
org_chats = []

for chat in chats:
    date_time = chat.split(' - ')[0]
    speaker_speech = chat.split(' - ')[1]
    date = date_time.split(', ')[0]
    time = date_time.split(', ')[1]
    speaker = speaker_speech.split(': ')[0]
    speech = speaker_speech.split(': ')[1]
    org_chats.append((date, time, speaker, speech))

chats = org_chats
chats
# Out:
# [('20/01/18', '03:00', 'Vaibhav Tripathi', 'Anar ka ho chuka'),
#  ('20/01/18', '03:00', 'Vaibhav Tripathi', 'Angoor ki baari'),
#  ('20/01/18', '03:00', 'Vaibhav Tripathi', '\xf0\x9f\x98\x9b'),
#  ('20/01/18', '03:00', 'Nupur', 'heheh chup raho'),
#  ('20/01/18', '03:00', 'Nupur', 'khaye waye kuch nahi anar'),
#  ('20/01/18', '03:00', 'Vaibhav Tripathi', 'Are khaye to yar'),
#  ('20/01/18',
#   '03:01',
#   'Vaibhav Tripathi',
#   'Aur usse bhi zyada effort chhilne me mare'),
#  ('20/01/18', '03:00', 'Nupur', 'fika diye'),
#  ('20/01/18', '03:01', 'Nupur', 'bhk'),
#  ('20/01/18', '03:01', 'Nupur', 'hum kitna badhiya easy se cheele the'),
#  ('20/01/18', '03:01', 'Vaibhav Tripathi', 'Tum pro ho be'),
#  ('20/01/18', '03:01', 'Vaibhav Tripathi', 'Hum nya nya seekhe the'),
#  ('20/01/18', '03:02', 'Vaibhav Tripathi', 'Aur kaafi kha bhi liye the'),
#  ('20/01/18', '03:02', 'Nupur', 'ji nahi'),
#  ('20/01/18', '03:02', 'Nupur', 'jhoot'),
#  ('20/01/18',
#   '03:02',
#   'Vaibhav Tripathi',
#   'Wo na tutorial k chkkr me kuch zyada hi chhil diye hum log'),
#  ('20/01/18', '03:02', 'Nupur', 'agle din kitna sara feka tha'),
#  ('20/01/18', '03:03', 'Nupur', 'thmhari diet kam hai yarrr'),
#  ('20/01/18', '03:03', 'Nupur', '\xf0\x9f\x98\x9e'),
#  ('20/01/18', '03:03', 'Nupur', 'hum bhi sahi se nahi kha paatr'),
#  ('20/01/18', '03:03', 'Nupur', 'pate*'),
#  ('20/01/18', '03:03', 'Nupur', 'tumhare chakkar me'),
#  ('20/01/18', '03:03', 'Vaibhav Tripathi', 'Haww'),
#  ('20/01/18', '03:03', 'Vaibhav Tripathi', 'Ye to glt h'),
#  ('20/01/18', '03:04', 'Vaibhav Tripathi', 'Tumhe to khana chahiye shi se na'),
#  ('20/01/18', '03:04', 'Nupur', 'pr fir tum nahi khate'),
#  ('20/01/18', '03:04', 'Nupur', 'tumse jyada nahi kha sakte na'),
#  ('20/01/18', '03:05', 'Vaibhav Tripathi', 'Hehehe'),
#  ('20/01/18', '03:05', 'Vaibhav Tripathi', 'Aisa kyun?'),
#  ('20/01/18', '03:05', 'Nupur', 'aisa hota hai'),
#  ('20/01/18',
#   '03:05',
#   'Nupur',
#   'ab socho physical strength me hum hara de tumhe'),
#  ('20/01/18', '03:05', 'Nupur', 'tab kaisa lagega'),
#  ('20/01/18', '03:05', 'Vaibhav Tripathi', 'Hume koi problem nhi h'),
#  ('20/01/18',
#   '03:06',
#   'Vaibhav Tripathi',
#   'Vaise bhi tumhare bicep muscles h humare nhi'),
#  ('20/01/18', '03:06', 'Vaibhav Tripathi', 'Makes sense agar hara do'),
#  ('20/01/18', '03:06', 'Vaibhav Tripathi', '\xf0\x9f\x98\x9b'),
#  ('20/01/18', '03:06', 'Nupur', 'hum marenge bohot'),
#  ('20/01/18', '03:06', 'Vaibhav Tripathi', 'Are to isme kya'),
#  ('20/01/18', '03:07', 'Vaibhav Tripathi', 'Tum to proudly dikhati ho bdhiya'),
#  ('20/01/18', '03:07', 'Nupur', 'ha wo toh thek hai'),
#  ('20/01/18',
#   '03:07',
#   'Nupur',
#   'lekin humne agar hara diya toh tmko kharab lagega for sure'),
#  ('20/01/18', '03:07', 'Nupur', 'utni ego toh hai tumhari'),
#  ('20/01/18', '03:08', 'Vaibhav Tripathi', 'Hehehe'),
#  ('20/01/18', '03:09', 'Vaibhav Tripathi', 'Ho skta h'),
#  ('20/01/18', '03:09', 'Nupur', 'toh waise hi hum zyada nahi kha sakte hain'),
#  ('20/01/18', '03:10', 'Vaibhav Tripathi', 'Ohhh female ego'),
#  ('20/01/18', '03:10', 'Vaibhav Tripathi', '\xf0\x9f\x98\x9b'),
#  ('20/01/18', '03:10', 'Nupur', 'mtlb not ego'),
#  ('20/01/18', '03:10', 'Nupur', 'aisa stereotype hai na'),
#  ('20/01/18', '03:10', 'Nupur', 'toh usko follow karne me'),
#  ('20/01/18', '03:11', 'Nupur', 'otherwise meri feminity kam ho jayegi'),
#  ('20/01/18', '03:11', 'Nupur', 'a hum kabhi bhi tapak sakte h'),
#  ('20/01/18', '03:11', 'Nupur', 'tez nend alert'),
#  ('20/01/18', '03:12', 'Vaibhav Tripathi', 'Hehehe'),
#  ('20/01/18', '03:12', 'Vaibhav Tripathi', 'Han theek h'),
#  ('20/01/18', '03:12', 'Vaibhav Tripathi', '\xf0\x9f\x98\x8a'),
#  ('20/01/18', '03:12', 'Nupur', 'kale angoor nahi pasand hai'),
#  ('20/01/18', '03:12', 'Nupur', '?'),
#  ('20/01/18', '03:12', 'Vaibhav Tripathi', 'Wo bhi h'),
#  ('20/01/18', '03:12', 'Vaibhav Tripathi', 'Pr hre wale usse thode zyada'),
#  ('20/01/18', '03:12', 'Nupur', 'wo pehle boht hi sexy lagte the'),
#  ('20/01/18', '03:12', 'Nupur', 'kabhi kabhi aate the isliye'),
#  ('20/01/18', '03:12', 'Vaibhav Tripathi', 'Haan'),
#  ('20/01/18',
#   '03:13',
#   'Vaibhav Tripathi',
#   'Lko me thele pe lata tha aur namak laga k deta tha'),
#  ('20/01/18', '03:13', 'Nupur', 'lekin mostly khatte nikalte hai'),
#  ('20/01/18', '03:13', 'Nupur', 'abe falsa pata hai?'),
#  ('20/01/18', '03:13', 'Vaibhav Tripathi', 'Haan'),
#  ('20/01/18', '03:13', 'Nupur', 'wo mast hote h'),
#  ('20/01/18', '03:13', 'Nupur', 'hume bade pasand hai'),
#  ('20/01/18', '03:13', 'Nupur', 'usme bhi namak laga ke deta h'),
#  ('20/01/18', '03:14', 'Nupur', 'yaarrr ab hume imli yaad a gayi'),
#  ('20/01/18', '03:14', 'Nupur', 'lal wali with chooran'),
#  ('20/01/18',
#   '03:14',
#   'Nupur',
#   '\xf0\x9f\x98\x8b\xf0\x9f\x98\x8b\xf0\x9f\x98\x8b'),
#  ('20/01/18', '03:14', 'Vaibhav Tripathi', 'Hehe'),
#  ('20/01/18',
#   '03:14',
#   'Vaibhav Tripathi',
#   'Yar ab to wahan bhi bnd ho gya ye sb'),
#  ('20/01/18', '03:14', 'Vaibhav Tripathi', 'A tumne amras khaya h?'),
#  ('20/01/18', '03:15', 'Nupur', 'ha'),
#  ('20/01/18', '03:15', 'Nupur', 'jo packet me aata tha?'),
#  ('20/01/18', '03:15', 'Vaibhav Tripathi', 'Nhi thele pr hi'),
#  ('20/01/18', '03:15', 'Vaibhav Tripathi', 'Hara hara'),
#  ('20/01/18', '03:15', 'Nupur', 'won nahi'),
#  ('20/01/18', '03:15', 'Nupur', 'wo*'),
#  ('20/01/18', '03:15', 'Vaibhav Tripathi', 'Yr wo imli se bhi khtta hota tha'),
#  ('20/01/18', '03:15', 'Vaibhav Tripathi', 'Next level'),
#  ('20/01/18', '03:15', 'Nupur', 'shayad khatta hota hai'),
#  ('20/01/18', '03:15', 'Nupur', 'wo khaya nahi jata be'),
#  ('20/01/18', '03:16', 'Nupur', 'green hota hai?'),
#  ('20/01/18', '03:16', 'Vaibhav Tripathi', 'Haan'),
#  ('20/01/18', '03:16', 'Nupur', 'taste kiya h'),
#  ('20/01/18', '03:16', 'Vaibhav Tripathi', 'Bolte h sookha aam hota h'),
#  ('20/01/18', '03:16', 'Vaibhav Tripathi', 'Pr ekdum alag shape me ata h'),
#  ('20/01/18', '03:17', 'Nupur', 'uske pieces krke deta h na'),
#  ('20/01/18', '03:17', 'Vaibhav Tripathi', 'Haan'),
#  ('20/01/18', '03:17', 'Nupur', 'wahi h fir'),
#  ('20/01/18', '03:18', 'Vaibhav Tripathi', 'Haan wo hum nhi khate the'),
#  ('20/01/18', '03:18', 'Vaibhav Tripathi', 'Lekin bikta bohot hi tha'),
#  ('20/01/18', '03:18', 'Nupur', 'toh fir kaahe itni der hum guess krte rahe'),
#  ('20/01/18',
#   '03:18',
#   'Nupur',
#   'hume laga tmhe pasand tha isliye bata rahe ho'),
#  ('20/01/18',
#   '03:19',
#   'Nupur',
#   '\xf0\x9f\xa4\xa6\xf0\x9f\x8f\xbb\xe2\x80\x8d\xe2\x99\x80\xf0\x9f\xa4\xa6\xf0\x9f\x8f\xbb\xe2\x80\x8d\xe2\x99\x80'),
#  ('20/01/18', '03:19', 'Vaibhav Tripathi', 'Nhi imli se yad aya hume'),
#  ('20/01/18', '03:19', 'Vaibhav Tripathi', 'Ki aisa bhi kuch tha'),
#  ('20/01/18', '03:20', 'Vaibhav Tripathi', 'Ajkl hume kiwi bda psnd a rha h'),
#  ('20/01/18', '03:20', 'Vaibhav Tripathi', 'Lekin bda hi mhnga h'),
#  ('20/01/18', '03:20', 'Vaibhav Tripathi', '\xf0\x9f\x98\x8f'),
#  ('20/01/18', '03:21', 'Nupur', 'hume taste nhi bhata'),
#  ('20/01/18', '03:21', 'Nupur', 'tum ameer ho be'),
#  ('20/01/18', '03:21', 'Nupur', 'khaya kro'),
#  ('20/01/18', '03:21', 'Vaibhav Tripathi', 'Are itna bhi nhi psnd'),
#  ('20/01/18', '03:21', 'Vaibhav Tripathi', 'Angoor sste h usse'),
#  ('20/01/18', '03:21', 'Vaibhav Tripathi', '\xf0\x9f\x98\x9b'),
#  ('20/01/18', '03:22', 'Nupur', 'hehe'),
#  ('20/01/18', '03:22', 'Vaibhav Tripathi', 'Aur btao'),
#  ('20/01/18', '03:24', 'Nupur', '\xf0\x9f\x96\xa4'),
#  ('20/01/18', '03:24', 'Nupur', '\xe2\x9d\xa4'),
#  ('20/01/18',
#   '03:25',
#   'Vaibhav Tripathi',
#   'A \xe2\x99\x91\xe2\x9b\x8e\xf0\x9f\x85\xbf\xe2\x9b\x8e\xe2\x99\x88'),
#  ('20/01/18', '03:25', 'Nupur', '\xe2\x99\x88\xf0\x9f\x85\xb1\xe2\x99\x88'),
#  ('20/01/18', '03:25', 'Vaibhav Tripathi', '\xf0\x9f\x98\x99'),
#  ('20/01/18', '03:26', 'Nupur', '\xf0\x9f\x99\x88'),
#  ('20/01/18', '03:26', 'Vaibhav Tripathi', '\xe2\x98\xba'),
#  ('20/01/18', '03:41', 'Vaibhav Tripathi', 'So gyi?'),
#  ('20/01/18', '03:42', 'Vaibhav Tripathi', 'Gn Nupurrr'),
#  ('20/01/18', '03:42', 'Vaibhav Tripathi', '\xe2\x9d\xa4'),
#  ('20/01/18', '12:49', 'Vaibhav Tripathi', 'Gm \xf0\x9f\x90\xa5'),
#  ('20/01/18', '12:51', 'Nupur', 'gm'),
#  ('20/01/18', '13:26', 'Nupur', 'aaj subah subah light nhi thi'),
#  ('20/01/18', '13:26', 'Nupur', 'bill nhi bhara tha toh kaat di'),
#  ('20/01/18', '13:26', 'Nupur', '\xf0\x9f\x98\x95\xf0\x9f\x98\x95'),
#  ('20/01/18', '13:26', 'Nupur', 'fir kam wali plus cook aye huye the'),
#  ('20/01/18', '13:27', 'Nupur', 'unko bhi dekhna tha'),
#  ('20/01/18', '13:27', 'Nupur', 'chakra gaye uthe hi'),
#  ('20/01/18',
#   '14:34',
#   'Nupur',
#   'hume apne logo ke liye movie yaad aa gayi... hum log harry potter dekhenge sath me 4th part se'),
#  ('20/01/18', '14:38', 'Vaibhav Tripathi', 'Light a gyi?'),
#  ('20/01/18', '14:38', 'Nupur', 'haa'),
#  ('20/01/18', '14:38', 'Vaibhav Tripathi', 'Acha'),
#  ('20/01/18', '14:38', 'Vaibhav Tripathi', 'Abhi movie dekh rhi?'),
#  ('20/01/18', '14:38', 'Nupur', 'nahi'),
#  ('20/01/18', '14:39', 'Nupur', 'bas lete hai'),
#  ('20/01/18', '14:39', 'Nupur', 'aaj pav bhaji bani h'),
#  ('20/01/18', '14:39', 'Nupur', '\xf0\x9f\x98\x8b'),
#  ('20/01/18', '14:39', 'Vaibhav Tripathi', 'Ohh wow'),
#  ('20/01/18', '14:39', 'Vaibhav Tripathi', 'Subh se kuch nhi khayi abhi tk?'),
#  ('20/01/18', '14:39', 'Nupur', 'chai paratha'),
#  ('20/01/18', '14:39', 'Nupur', 'yar paratha bhi mast bana tha'),
#  ('20/01/18', '14:40', 'Nupur', 'pyaz mirch etc'),
#  ('20/01/18', '14:40', 'Vaibhav Tripathi', 'A same fir se \xf0\x9f\x98\x8a'),
#  ('20/01/18', '14:40', 'Nupur', '\xf0\x9f\x91\x8f\xf0\x9f\x8f\xbb'),
#  ('20/01/18', '14:40', 'Vaibhav Tripathi', 'Humne bs abhi abhi kiya h nashta'),
#  ('20/01/18', '14:40', 'Vaibhav Tripathi', '\xf0\x9f\x98\x9b'),
#  ('20/01/18', '14:40', 'Nupur', 'der se uthe?'),
#  ('20/01/18', '14:41', 'Vaibhav Tripathi', 'Haan bs jb tumko msg kiya tha'),
#  ('20/01/18',
#   '14:41',
#   'Vaibhav Tripathi',
#   'Aaj sb humse pehle uth gye yahan pe'),
#  ('20/01/18', '14:41', 'Vaibhav Tripathi', 'Pehli br'),
#  ('20/01/18', '14:41', 'Nupur', 'chlo good'),
#  ('20/01/18', '14:41', 'Nupur', 'sona chaiye khoob sara'),
#  ('20/01/18', '14:41', 'Vaibhav Tripathi', 'Haan'),
#  ('20/01/18', '14:41', 'Vaibhav Tripathi', 'Aur pata h uthe kaise'),
#  ('20/01/18', '14:42', 'Vaibhav Tripathi', 'Radha k call se \xf0\x9f\x98\x8f'),
#  ('20/01/18', '14:42', 'Nupur', 'kyu'),
#  ('20/01/18',
#   '14:42',
#   'Vaibhav Tripathi',
#   'Bol rhe the ki kuch screening round lene h nyi hiring k liye'),
#  ('20/01/18', '14:42', 'Vaibhav Tripathi', 'Puch rhe the kroge ki nhi'),
#  ('20/01/18', '14:42', 'Nupur', 'wowww'),
#  ('20/01/18',
#   '14:42',
#   'Nupur',
#   '\xf0\x9f\x91\x8f\xf0\x9f\x8f\xbb\xf0\x9f\x91\x8f\xf0\x9f\x8f\xbb\xf0\x9f\x91\x8f\xf0\x9f\x8f\xbb\xf0\x9f\x91\x8f\xf0\x9f\x8f\xbb\xf0\x9f\x91\x8f\xf0\x9f\x8f\xbb'),
#  ('20/01/18',
#   '14:42',
#   'Nupur',
#   '\xf0\x9f\x98\x83\xf0\x9f\x98\x83\xf0\x9f\x98\x83'),
#  ('20/01/18', '14:42', 'Vaibhav Tripathi', 'Vaise to kaam bdha rhe'),
#  ('20/01/18', '14:43', 'Vaibhav Tripathi', 'Pr humare liye nyi cheez h'),
#  ('20/01/18', '14:43', 'Vaibhav Tripathi', 'To humne bola ki le lenge'),
#  ('20/01/18', '14:43', 'Nupur', 'yar yeh toh mast hai'),
#  ('20/01/18', '14:43', 'Vaibhav Tripathi', 'Haan dekho'),
#  ('20/01/18', '14:43', 'Vaibhav Tripathi', 'Lg to rha h ki shi rhega'),
#  ('20/01/18', '14:44', 'Nupur', 'maja ayegi'),
#  ('20/01/18', '14:44', 'Vaibhav Tripathi', 'Haan'),
#  ('20/01/18', '14:44', 'Vaibhav Tripathi', 'Tum btao'),
#  ('20/01/18', '14:44', 'Vaibhav Tripathi', 'Kya krogi aaj?'),
#  ('20/01/18', '14:45', 'Nupur', 'aaj kuch nahi yar'),
#  ('20/01/18', '14:45', 'Nupur', 'apna kaam karenge'),
#  ('20/01/18', '14:46', 'Vaibhav Tripathi', 'Arey'),
#  ('20/01/18', '14:46', 'Vaibhav Tripathi', 'Weekend pe kaam \xf0\x9f\x98\xb1'),
#  ('20/01/18', '14:46', 'Nupur', 'ha yar thoda boht cv update karne me'),
#  ('20/01/18', '14:47', 'Vaibhav Tripathi', 'Haan wo theek h fir bhi'),
#  ('20/01/18', '14:47', 'Vaibhav Tripathi', 'Bhut sundr wala bna dena'),
#  ('20/01/18', '14:47', 'Vaibhav Tripathi', 'Ekdum apni trh'),
#  ('20/01/18', '14:47', 'Vaibhav Tripathi', '\xf0\x9f\x98\x8a'),
#  ('20/01/18', '14:47', 'Nupur', 'heheheh'),
#  ('20/01/18', '14:47', 'Nupur', 'makeup kr denge'),
#  ('20/01/18', '14:48', 'Vaibhav Tripathi', 'Hehe haan'),
#  ('20/01/18',
#   '14:48',
#   'Vaibhav Tripathi',
#   'Tumhare brbr sundr thodi na ho paega koi'),
#  ('20/01/18', '14:48', 'Vaibhav Tripathi', 'Makeup ki zrurt to pdegi hi'),
#  ('20/01/18', '14:48', 'Vaibhav Tripathi', '\xf0\x9f\x98\x9b'),
#  ('20/01/18', '14:48', 'Nupur', 'hehehehe'),
#  ('20/01/18', '14:48', 'Nupur', 'aur bolo'),
#  ('20/01/18', '14:49', 'Nupur', 'accha lag raha subah subah'),
#  ('20/01/18',
#   '14:49',
#   'Nupur',
#   '\xf0\x9f\x98\x9d\xf0\x9f\x98\x9d\xf0\x9f\x98\x9d'),
#  ('20/01/18',
#   '14:49',
#   'Vaibhav Tripathi',
#   'Are subah kya. Tum to subah sham dopahar rat \xf0\x9f\x98\x89'),
#  ('20/01/18', '14:49', 'Vaibhav Tripathi', 'Utni hi sundr lgti ho'),
#  ('20/01/18', '14:49', 'Nupur', 'hehehehe'),
#  ('20/01/18', '14:49', 'Nupur', '\xf0\x9f\x98\x82'),
#  ('20/01/18', '14:50', 'Nupur', 'mast tareef krte ho be'),
#  ('20/01/18', '14:50', 'Vaibhav Tripathi', 'Are jb inspiration ho samne aisi'),
#  ('20/01/18', '14:50', 'Vaibhav Tripathi', 'To tareef naturally niklti h'),
#  ('20/01/18', '14:51', 'Vaibhav Tripathi', 'I am just an instrument'),
#  ('20/01/18', '14:51', 'Vaibhav Tripathi', '\xf0\x9f\x98\x9b'),
#  ('20/01/18', '14:51', 'Nupur', 'hatt'),
#  ('20/01/18', '14:51', 'Nupur', 'yeh last line ajeeb thi'),
#  ('20/01/18', '14:51', 'Nupur', 'undo that'),
#  ('20/01/18', '14:51', 'Vaibhav Tripathi', 'Are ye to bhut purani h'),
#  ('20/01/18', '14:52', 'Vaibhav Tripathi', 'Acha theek'),
#  ('20/01/18', '14:52', 'Vaibhav Tripathi', 'Ctrl Z'),
#  ('20/01/18', '14:52', 'Nupur', 'thek'),
#  ('20/01/18', '14:52', 'Vaibhav Tripathi', 'Aur btao'),
#  ('20/01/18', '14:52', 'Nupur', 'aurr yar bas lete h'),
#  ('20/01/18', '14:52', 'Nupur', 'sarla kamini abhi tk ayi nahi'),
#  ('20/01/18', '14:52', 'Nupur', 'subah se call laga rahe hai'),
#  ('20/01/18', '14:52', 'Vaibhav Tripathi', '\xf0\x9f\x98\xa1'),
#  ('20/01/18', '14:52', 'Nupur', 'kriti bhi gayi bahar'),
#  ('20/01/18', '14:53', 'Nupur', 'tm kyu gussa rhe'),
#  ('20/01/18',
#   '14:53',
#   'Vaibhav Tripathi',
#   'Uski vjh se hum nhi mil pae tumse'),
#  ('20/01/18', '14:53', 'Nupur', 'bhk'),
#  ('20/01/18', '14:53', 'Vaibhav Tripathi', 'Aur wo bhi nhi ayi'),
#  ('20/01/18', '14:53', 'Nupur', 'hum waise bhi na milte be'),
#  ('20/01/18', '14:53', 'Vaibhav Tripathi', 'Kyun?'),
#  ('20/01/18', '14:53', 'Nupur', 'mera ghar me rehne ka man tha'),
#  ('20/01/18',
#   '14:54',
#   'Vaibhav Tripathi',
#   'Tum ghr me reh skti thi. Hum tbbhi mil lete'),
#  ('20/01/18', '14:54', 'Vaibhav Tripathi', '\xf0\x9f\x98\x9b'),
#  ('20/01/18', '14:54', 'Nupur', 'ji nahi'),
#  ('20/01/18', '14:54', 'Nupur', 'ghar me kafi log the waise bhi'),
#  ('20/01/18',
#   '14:54',
#   'Nupur',
#   'plus kriti ko shaq ho gaya h... boht baar pooch chuki hai'),
#  ('20/01/18', '14:55', 'Nupur', 'tm uske samne nahi aa sakte'),
#  ('20/01/18', '14:55', 'Vaibhav Tripathi', 'Ohh'),
#  ('20/01/18', '14:56', 'Nupur', 'yar hum log 30 ko bahar jayenge kya?'),
#  ('20/01/18',
#   '14:57',
#   'Vaibhav Tripathi',
#   'Haan yaar bilkul \xf0\x9f\x98\x8a'),
#  ('20/01/18', '14:57', 'Vaibhav Tripathi', 'Bday kaun ghr me rehta h'),
#  ('20/01/18',
#   '14:57',
#   'Nupur',
#   'ha toh hum wahi soch rahe ki mere pas naya kapda nahi h'),
#  ('20/01/18', '14:57', 'Nupur', '\xe2\x98\xb9'),
#  ('20/01/18', '14:57', 'Nupur', 'hum kya pehnenge'),
#  ('20/01/18',
#   '14:58',
#   'Vaibhav Tripathi',
#   'Tum agle weekend ek din nikal lo bs'),
#  ('20/01/18', '14:58', 'Vaibhav Tripathi', 'Baki humpe chhod do'),
#  ('20/01/18', '14:58', 'Vaibhav Tripathi', '\xf0\x9f\x98\x8a'),
#  ('20/01/18',
#   '14:58',
#   'Nupur',
#   'oln order kiya hai lekin pata nahi tb tak ayega ya nahi'),
#  ('20/01/18', '14:58', 'Nupur', 'hum mall se nahi kharedenge yar'),
#  ('20/01/18', '14:58', 'Nupur', 'sale ke bina'),
#  ('20/01/18', '14:58', 'Nupur', 'bohot mehnge hote hai'),
#  ('20/01/18', '14:58', 'Vaibhav Tripathi', 'Are yar ye sb nhi kro'),
#  ('20/01/18', '14:59', 'Vaibhav Tripathi', 'Acha sale wale me jaenge'),
#  ('20/01/18', '14:59', 'Vaibhav Tripathi', 'Pkka'),
#  ('20/01/18', '14:59', 'Nupur', 'lagi hi nahi hogi'),
#  ('20/01/18', '14:59', 'Nupur', 'abhi chal rahi hai kya??'),
#  ('20/01/18', '14:59', 'Vaibhav Tripathi', 'Tum chlo to Nupur'),
#  ('20/01/18', '14:59', 'Vaibhav Tripathi', 'Haan almost sbme h'),
#  ('20/01/18', '14:59', 'Nupur', 'bhk jhoote'),
#  ('20/01/18', '14:59', 'Vaibhav Tripathi', 'Are sch me'),
#  ('20/01/18', '14:59', 'Nupur', 'tumko kaise pata'),
#  ('20/01/18', '15:00', 'Vaibhav Tripathi', 'Humare pas msg ate rehte h'),
#  ('20/01/18', '15:00', 'Nupur', 'kisme hai?'),
#  ('20/01/18',
#   '15:00',
#   'Vaibhav Tripathi',
#   'Mark and spencer k a rhe. Shoppers stop etc sbme h'),
#  ('20/01/18', '15:01', 'Nupur', 'lifestyle?'),
#  ('20/01/18', '15:01', 'Vaibhav Tripathi', 'Usme bhi h'),
#  ('20/01/18', '15:01', 'Vaibhav Tripathi', 'Abe chlenge to aur pta chlega na'),
#  ('20/01/18', '15:01', 'Nupur', 'accha'),
#  ('20/01/18', '15:01', 'Nupur', 'yar oln dekh lenge'),
#  ('20/01/18', '15:01', 'Nupur', 'pehle'),
#  ('20/01/18', '15:02', 'Vaibhav Tripathi', 'Nhi na'),
#  ('20/01/18',
#   '15:02',
#   'Vaibhav Tripathi',
#   'Oln dekhke fir offline smjh nhi ata'),
#  ('20/01/18', '15:02', 'Nupur', 'hhaha'),
#  ('20/01/18', '15:02', 'Nupur', 'kuch bhi'),
#  ('20/01/18', '15:02', 'Nupur', '\xf0\x9f\x98\x9d\xf0\x9f\x98\x9d'),
#  ('20/01/18', '15:02', 'Vaibhav Tripathi', 'Hehehe'),
#  ('20/01/18', '15:03', 'Vaibhav Tripathi', 'To tum ek din free rkh lo'),
#  ('20/01/18', '15:03', 'Vaibhav Tripathi', 'Aur suno'),
#  ('20/01/18', '15:03', 'Vaibhav Tripathi', '31st ki leave lelo'),
#  ('20/01/18', '15:04', 'Vaibhav Tripathi', 'Kahi chlte h'),
#  ('20/01/18', '15:04', 'Nupur', 'abe 30 ko ja rahe toh h'),
#  ('20/01/18', '15:04', 'Vaibhav Tripathi', '30 ko to rat me jaenge'),
#  ('20/01/18', '15:05', 'Vaibhav Tripathi', 'Zyada time kaha milega'),
#  ('20/01/18', '15:05', 'Nupur', '31 ko fir se?'),
#  ('20/01/18', '15:05', 'Vaibhav Tripathi', 'Haan \xf0\x9f\x98\x8a'),
#  ('20/01/18', '15:06', 'Nupur', 'kaha pe?'),
#  ('20/01/18', '15:06', 'Vaibhav Tripathi', 'Wo dekh lnge'),
#  ('20/01/18',
#   '15:07',
#   'Nupur',
#   'abe agar sham tak nikalna h toh ofc jaa sakte hai'),
#  ('20/01/18',
#   '15:08',
#   'Vaibhav Tripathi',
#   'Office se ate ate bhut time ho jata h be \xf0\x9f\x98\x94'),
#  ('20/01/18', '15:08', 'Vaibhav Tripathi', 'Fir whi hoga khao piyo niklo'),
#  ('20/01/18', '15:08', 'Nupur', 'tumko aur kya karna h'),
#  ('20/01/18', '15:08', 'Nupur', '\xf0\x9f\x99\x84'),
#  ('20/01/18',
#   '15:08',
#   'Vaibhav Tripathi',
#   'Are thoda aram se baithte kahi bina jldi baazi k'),
#  ('20/01/18', '15:09', 'Vaibhav Tripathi', 'Abhi soche nhi h hum'),
#  ('20/01/18', '15:09', 'Nupur', 'hehehe'),
#  ('20/01/18', '15:09', 'Nupur', 'us din hi dekhenge jo plan banega'),
#  ('20/01/18', '15:09', 'Nupur', 'nahi wfh le lenge'),
#  ('20/01/18', '15:09', 'Nupur', 'nahi toh*'),
#  ('20/01/18', '15:09', 'Vaibhav Tripathi', 'Theek h'),
#  ('20/01/18', '15:10', 'Nupur', 'kahi ngo wala scene hai kya?'),
#  ('20/01/18', '15:10', 'Nupur', 'ya kuch bhi aisa'),
#  ('20/01/18', '15:10', 'Vaibhav Tripathi', 'Humne pta kiya tha'),
#  ('20/01/18', '15:10', 'Vaibhav Tripathi', 'Ek ldka liya h meri team me'),
#  ('20/01/18', '15:11', 'Vaibhav Tripathi', 'CRY h ek ngo'),
#  ('20/01/18', '15:11', 'Vaibhav Tripathi', 'All over Bangalore h uske center'),
#  ('20/01/18',
#   '15:11',
#   'Vaibhav Tripathi',
#   'Lekin wo bol rha tha ki serve krne k liye membership leni pdegi'),
#  ('20/01/18',
#   '15:11',
#   'Vaibhav Tripathi',
#   'Aur orientation krwate h wo log khoob lmba'),
#  ('20/01/18', '15:12', 'Vaibhav Tripathi', 'Weekend pe jana pdega'),
#  ('20/01/18',
#   '15:12',
#   'Vaibhav Tripathi',
#   'Agar tum free hogi agle weekend to chl skte h'),
#  ('20/01/18', '15:12', 'Vaibhav Tripathi', '\xf0\x9f\x98\x8a'),
#  ('20/01/18', '15:12', 'Nupur', 'abe yeh toh bada professional hai'),
#  ('20/01/18', '15:13', 'Vaibhav Tripathi', 'Haan'),
#  ('20/01/18',
#   '15:13',
#   'Vaibhav Tripathi',
#   'Wo bola h pta krne k liye ki agar ek din volunteer krna ho to'),
#  ('20/01/18', '15:13', 'Vaibhav Tripathi', '*Usse'),
#  ('20/01/18', '15:13', 'Nupur', 'thek hai'),
#  ('20/01/18', '15:13', 'Nupur', 'waise sarla wala toh hai lekin'),
#  ('20/01/18', '15:14', 'Nupur', 'kannada wali problem hai'),
#  ('20/01/18', '15:14', 'Nupur', 'bacche samajhte nahi hai'),
#  ('20/01/18', '15:14', 'Vaibhav Tripathi', 'Are mil jaega koi to'),
#  ('20/01/18', '15:14', 'Vaibhav Tripathi', 'Lekin 31 ko wahan nhi'),
#  ('20/01/18', '15:14', 'Vaibhav Tripathi', 'Us din mze krenge'),
#  ('20/01/18', '15:14', 'Vaibhav Tripathi', '\xf0\x9f\x98\x8a'),
#  ('20/01/18', '15:15', 'Vaibhav Tripathi', 'Wahan pehle ya baad me'),
#  ('20/01/18', '15:15', 'Nupur', 'abe kya maje krenge'),
#  ('20/01/18',
#   '15:15',
#   'Vaibhav Tripathi',
#   'Are abhi itna detail me nhi soche h. Krenge kuch to'),
#  ('20/01/18', '15:16', 'Nupur', 'rahul ko bula lete hai'),
#  ('20/01/18', '15:16', 'Nupur', 'khelenge fir'),
#  ('20/01/18', '15:16', 'Vaibhav Tripathi', 'Theek h'),
#  ('20/01/18',
#   '15:16',
#   'Nupur',
#   'waise hume toh ngo wala hi sahi lag raha hai'),
#  ('20/01/18', '15:16', 'Vaibhav Tripathi', 'Okay'),
#  ('20/01/18', '15:16', 'Vaibhav Tripathi', 'Tumhara bday h'),
#  ('20/01/18', '15:16', 'Vaibhav Tripathi', 'Whatever you say'),
#  ('20/01/18', '15:16', 'Vaibhav Tripathi', '\xf0\x9f\x98\x8a'),
#  ('20/01/18', '15:16', 'Nupur', 'hehhe'),
#  ('20/01/18', '15:16', 'Vaibhav Tripathi', 'Vaise anyday'),
#  ('20/01/18', '15:16', 'Vaibhav Tripathi', 'Whatever you say'),
#  ('20/01/18', '15:17', 'Vaibhav Tripathi', '\xf0\x9f\x98\x9b'),
#  ('20/01/18', '15:17', 'Nupur', '\xf0\x9f\x98\x82'),
#  ('20/01/18', '15:17', 'Nupur', 'itte bhi sedhe nahi ho'),
#  ('20/01/18', '15:17', 'Vaibhav Tripathi', 'Are ekdum itne hi seedhe h hum'),
#  ('20/01/18',
#   '15:18',
#   'Vaibhav Tripathi',
#   'Theek h acha wo pta krte h ki kahan jana h'),
#  ('20/01/18', '15:18', 'Vaibhav Tripathi', 'Kb jana h bd me dekh lnge'),
#  ('20/01/18',
#   '15:18',
#   'Vaibhav Tripathi',
#   'Lekin agle hfte kpde lene jaenge okk? \xf0\x9f\x98\x8a'),
#  ('20/01/18', '15:19', 'Nupur', 'abhi agle hafte ka pakka nahi hai baki ok'),
#  ('20/01/18', '15:19', 'Nupur', '\xf0\x9f\x91\x8d\xf0\x9f\x8f\xbb'),
#  ('20/01/18', '15:19', 'Vaibhav Tripathi', 'Agle hfte ja rhi kahin?'),
#  ('20/01/18', '15:19', 'Nupur', 'hmm wahi decide nahi hua hai'),
#  ('20/01/18', '15:19', 'Vaibhav Tripathi', 'Okk'),
#  ('20/01/18',
#   '15:20',
#   'Vaibhav Tripathi',
#   'Acha hum khana kha rhe. Bd me bt krte h \xf0\x9f\x98\x8a'),
#  ('20/01/18', '15:20', 'Nupur', 'okiess'),
#  ('20/01/18', '22:51', 'Vaibhav Tripathi', 'Nupurrr'),
#  ('21/01/18', '00:16', 'Vaibhav Tripathi', 'Kahan ho?'),
#  ('21/01/18', '00:16', 'Nupur', 'ghar me'),
#  ('21/01/18', '00:16', 'Nupur', '\xf0\x9f\x98\x8a\xf0\x9f\x98\x8a'),
#  ('21/01/18', '00:16', 'Nupur', 'kaise ho'),
#  ('21/01/18', '00:16', 'Vaibhav Tripathi', 'Theek h'),
#  ('21/01/18', '00:16', 'Vaibhav Tripathi', 'Dd k yahan h'),
#  ('21/01/18', '00:17', 'Vaibhav Tripathi', 'Tum kaisi ho?'),
#  ('21/01/18', '00:17', 'Nupur', 'hum acche h'),
#  ('21/01/18', '00:17', 'Nupur', 'aurrr'),
#  ('21/01/18', '00:17', 'Nupur', 'kya khaya ??'),
#  ('21/01/18',
#   '00:17',
#   'Vaibhav Tripathi',
#   'Wahi bnwaya fir se jo kl bheja tha tumhe'),
#  ('21/01/18', '00:18', 'Vaibhav Tripathi', 'Sath me garlic bread'),
#  ('21/01/18', '00:18', 'Vaibhav Tripathi', 'Bhut hi awesome tha'),
#  ('21/01/18', '00:18', 'Vaibhav Tripathi', '\xf0\x9f\x98\x8a'),
#  ('21/01/18', '00:18', 'Vaibhav Tripathi', 'Tumne kya kiya?'),
#  ('21/01/18', '00:29', 'Nupur', 'humne bas batiaya'),
#  ('21/01/18', '00:30', 'Nupur', 'sarla aa gyi'),
#  ('21/01/18', '00:30', 'Nupur', 'big boss khela\xf0\x9f\x98\x9b'),
#  ('21/01/18', '00:30', 'Nupur', 'pav bhaji hi khai'),
#  ('21/01/18', '00:30', 'Nupur', 'aur bas'),
#  ('21/01/18', '00:30', 'Vaibhav Tripathi', 'Khelte kaise h?'),
#  ('21/01/18', '00:44', 'Nupur', 'abe bas panchayat lagate hai'),
#  ('21/01/18', '00:45', 'Nupur', 'usko hi hum log bolte h big boss'),
#  ('21/01/18', '00:46', 'Nupur', 'tum batao'),
#  ('21/01/18', '00:46', 'Nupur', 'aaj rukoge?'),
#  ('21/01/18', '00:47', 'Vaibhav Tripathi', 'Hehehe acha'),
#  ('21/01/18', '00:47', 'Vaibhav Tripathi', 'Haan aj ruk rhe'),
#  ('21/01/18', '00:47', 'Vaibhav Tripathi', 'Kl subah subah vapas ghr'),
#  ('21/01/18', '00:47', 'Nupur', 'humne sarla se pata chala'),
#  ('21/01/18', '00:48', 'Nupur', 'kormangala me ek ngo hai'),
#  ('21/01/18', '00:48', 'Nupur', 'waha ek din ke liye ja sakte hai'),
#  ('21/01/18', '00:48', 'Vaibhav Tripathi', 'Ohh shi'),
#  ('21/01/18', '00:48', 'Vaibhav Tripathi', 'Kya kr skte h wahan?'),
#  ('21/01/18', '00:48', 'Nupur', 'shayad bacho ka hai'),
#  ('21/01/18', '00:49', 'Nupur', 'toh muslim bacche hai'),
#  ('21/01/18', '00:49', 'Nupur', 'unko padha sakte hai'),
#  ('21/01/18', '00:49', 'Vaibhav Tripathi', 'Nice \xf0\x9f\x98\x8a'),
#  ('21/01/18', '00:49', 'Vaibhav Tripathi', 'Usse le lena details'),
#  ('21/01/18', '00:49', 'Vaibhav Tripathi', 'Aur koi website vgairah ho to'),
#  ('21/01/18', '00:50', 'Nupur', 'theek hai'),
#  ('21/01/18', '00:51', 'Nupur', 'sarla janti hai shayad kisi ko waha pe'),
#  ('21/01/18', '00:51', 'Nupur', 'pooch lenge'),
#  ('21/01/18',
#   '00:51',
#   'Vaibhav Tripathi',
#   'Haan \xf0\x9f\x91\x8f\xf0\x9f\x8f\xbb'),
#  ('21/01/18',
#   '00:51',
#   'Vaibhav Tripathi',
#   'Kuch notebooks pens vgairah bhi lete jaenge'),
#  ('21/01/18', '00:51', 'Vaibhav Tripathi', '\xf0\x9f\x98\x8a'),
#  ('21/01/18', '00:51', 'Nupur', 'bilkul'),
#  ('21/01/18', '00:52', 'Nupur', 'do din toh jayenge hi'),
#  ('21/01/18', '00:52', 'Vaibhav Tripathi', 'Done'),
#  ('21/01/18', '01:01', 'Vaibhav Tripathi', 'Vartika Kapoor ko janti ho tum?'),
#  ('21/01/18', '01:01', 'Nupur', 'meri behen hai'),
#  ('21/01/18', '01:02', 'Nupur', 'tumko kaise pata???'),
#  ('21/01/18',
#   '01:02',
#   'Vaibhav Tripathi',
#   'Fir shi h. Tumne Amazon pe order kiya h na kuch shayad'),
#  ('21/01/18', '01:02', 'Nupur', 'arey haa'),
#  ('21/01/18', '01:02', 'Nupur', 'hum batane wale the'),
#  ('21/01/18', '01:03', 'Nupur', 'sry'),
#  ('21/01/18', '01:03', 'Nupur', 'bhool gaye'),
#  ('21/01/18', '01:03', 'Nupur', 'joote order kiye the prime me sale thi toh'),
#  ('21/01/18',
#   '01:03',
#   'Vaibhav Tripathi',
#   'Are theek h hum smjh gye the \xf0\x9f\x98\x8a'),
#  ('21/01/18', '01:03', 'Nupur', 'uska aaj bday tha'),
#  ('21/01/18', '01:04', 'Vaibhav Tripathi', 'Bdhiya h joote'),
#  ('21/01/18', '01:05', 'Nupur', 'ha usne hi pasand kiya tha'),
#  ('21/01/18', '01:07', 'Vaibhav Tripathi', '<Media omitted>'),
#  ('21/01/18', '01:13', 'Nupur', 'haa'),
#  ('21/01/18', '01:13', 'Vaibhav Tripathi', 'Theek'),
#  ('21/01/18', '01:13', 'Nupur', 'order kr re?'),
#  ('21/01/18', '01:13', 'Vaibhav Tripathi', 'Haan'),
#  ('21/01/18', '01:14', 'Vaibhav Tripathi', 'Kr de na?'),
#  ('21/01/18', '01:16', 'Nupur', 'aur koi option hai ??'),
#  ('21/01/18',
#   '01:17',
#   'Vaibhav Tripathi',
#   'Yr bhut sare shi lg rhe the hume to myntra pe. Ye simple sa tha aur sasta bhi mil rha abhi'),
#  ('21/01/18', '01:17', 'Vaibhav Tripathi', '\xf0\x9f\x98\x8a'),
#  ('21/01/18', '01:19', 'Nupur', 'amazon pe dekho'),
#  ('21/01/18', '01:20', 'Nupur', 'hum dekhe ???'),
#  ('21/01/18', '01:20', 'Vaibhav Tripathi', 'Bilkul \xf0\x9f\x98\x8a'),
#  ('21/01/18', '01:21', 'Nupur', 'thek hai'),
#  ('21/01/18', '01:21', 'Nupur', 'abhi dekhte hai'),
#  ('21/01/18', '01:22', 'Vaibhav Tripathi', 'Okk \xf0\x9f\x98\x8a'),
#  ('21/01/18', '01:22', 'Vaibhav Tripathi', 'Sarla wale ngo ka nam btao'),
#  ('21/01/18', '01:22', 'Vaibhav Tripathi', 'Hum wo dekhte h'),
#  ('21/01/18', '01:22', 'Nupur', 'robin hood academy'),
#  ('21/01/18', '01:23', 'Nupur', 'rajendra nagar hai'),
#  ('21/01/18', '01:23', 'Nupur', 'inside kormangala'),
#  ('21/01/18', '01:23', 'Vaibhav Tripathi', 'Theek'),
#  ('21/01/18', '01:47', 'Nupur', 'kya kar rahe ho'),
#  ('21/01/18', '01:48', 'Vaibhav Tripathi', 'Kuch nhi'),
#  ('21/01/18', '01:48', 'Vaibhav Tripathi', 'Bs baithe h'),
#  ('21/01/18', '01:48', 'Nupur', 'bas??'),
#  ('21/01/18',
#   '01:48',
#   'Vaibhav Tripathi',
#   'Humne register kr diya robin hood academy me'),
#  ('21/01/18',
#   '01:48',
#   'Vaibhav Tripathi',
#   'Un logo ne bola h ko contact krenge'),
#  ('21/01/18', '01:49', 'Vaibhav Tripathi', 'Nhi to hum khud hi call kr lenge'),
#  ('21/01/18', '01:49', 'Nupur', 'wahh'),
#  ('21/01/18', '01:49', 'Nupur', 'badi tezi me'),
#  ('21/01/18', '01:49', 'Nupur', '\xf0\x9f\x98\x9b'),
#  ('21/01/18', '01:49', 'Nupur', 'chalo accha h'),
#  ('21/01/18', '01:50', 'Vaibhav Tripathi', 'Form hi to bhrna tha'),
#  ('21/01/18', '01:50', 'Vaibhav Tripathi', '\xf0\x9f\x98\x9b'),
#  ('21/01/18', '01:50', 'Vaibhav Tripathi', 'Tum btao'),
#  ('21/01/18', '01:50', 'Vaibhav Tripathi', 'Kya kr rhi?'),
#  ('21/01/18', '01:50', 'Nupur', 'wahi joota dekh rahe hai'),
#  ('21/01/18', '01:51', 'Nupur', 'acha wo jo dd ne banaya tha wo kya tha??'),
#  ('21/01/18', '01:51', 'Nupur', 'vegetables thi?'),
#  ('21/01/18',
#   '01:51',
#   'Vaibhav Tripathi',
#   'Haan wo na pasta wala sauce tha usme spinach corn etc dal diya usne'),
#  ('21/01/18', '01:51', 'Vaibhav Tripathi', 'Basically pasta without pasta'),
#  ('21/01/18', '01:51', 'Vaibhav Tripathi', '\xf0\x9f\x98\x9b'),
#  ('21/01/18', '01:51', 'Nupur', 'hehehe'),
#  ('21/01/18', '01:52', 'Nupur', 'abe badhiya be'),
#  ('21/01/18', '01:52', 'Nupur', 'sach me yum dikh raha tha'),
#  ('21/01/18',
#   '01:52',
#   'Vaibhav Tripathi',
#   'Haan yr isiliye to aaj fir bnwaye. Tha bhi bhut sahi'),
#  ('21/01/18',
#   '01:52',
#   'Vaibhav Tripathi',
#   'Aur garlic bread k sath bdhiya ja rha tha'),
#  ('21/01/18', '01:54', 'Nupur', 'kaha se seekha??'),
#  ('21/01/18',
#   '01:54',
#   'Vaibhav Tripathi',
#   'Are wo khud hi se experiment krti rehti h'),
#  ('21/01/18',
#   '01:55',
#   'Vaibhav Tripathi',
#   'Aur agar acha bn jata h to hum a jate h khane'),
#  ('21/01/18', '01:55', 'Vaibhav Tripathi', '\xf0\x9f\x98\x9b'),
#  ('21/01/18', '01:55', 'Nupur', 'hehehe'),
#  ('21/01/18',
#   '01:55',
#   'Nupur',
#   'waise spinach corn humne suna hai acchi hota hai'),
#  ('21/01/18', '01:55', 'Nupur', 'accha*'),
#  ('21/01/18', '01:56', 'Nupur', 'lekin spinach sunke kabhi order nahi kiya'),
#  ('21/01/18', '01:56', 'Vaibhav Tripathi', 'Hehe'),
#  ('21/01/18', '01:56', 'Vaibhav Tripathi', 'Shi bat'),
#  ('21/01/18', '01:56', 'Vaibhav Tripathi', 'Hum bhi na krte'),
#  ('21/01/18', '01:56', 'Vaibhav Tripathi', 'Lekin uska taste aya nhi'),
#  ('21/01/18', '01:57', 'Nupur', 'aur batao'),
#  ('21/01/18', '01:58', 'Nupur', 'sneakers jaisa chaiye kya?'),
#  ('21/01/18',
#   '01:58',
#   'Vaibhav Tripathi',
#   'Yar hume zyada antr smjh to nhi ata shi btaye to \xf0\x9f\x98\x9b'),
#  ('21/01/18',
#   '01:58',
#   'Vaibhav Tripathi',
#   'Pr running shoe category me jo dikh rhe the'),
#  ('21/01/18', '01:58', 'Vaibhav Tripathi', 'Wo shi lg rhe the'),
#  ('21/01/18', '01:59', 'Nupur', 'hehe theek hai'),
#  ('21/01/18', '01:59', 'Nupur', 'ek category hai badminton shoes'),
#  ('21/01/18', '01:59', 'Nupur', 'wo le le \xf0\x9f\x98\x9b\xf0\x9f\x98\x9b'),
#  ('21/01/18', '01:59', 'Vaibhav Tripathi', 'Are nhi wo h'),
#  ('21/01/18', '02:00', 'Nupur', 'accha wo hai?'),
#  ('21/01/18',
#   '02:00',
#   'Vaibhav Tripathi',
#   'Haan uska sole alag hota h na. Uske bina ghusne nhi dete wooden court me'),
#  ('21/01/18', '02:00', 'Vaibhav Tripathi', 'To wo le liya tha humne'),
#  ('21/01/18',
#   '02:01',
#   'Vaibhav Tripathi',
#   'Actually humare pas badminton aur gym k liye joote h. Bahar jane k liye ache joote nhi h'),
#  ('21/01/18', '02:01', 'Vaibhav Tripathi', '\xf0\x9f\x98\x9b'),
#  ('21/01/18', '02:01', 'Nupur', 'wahh beta'),
#  ('21/01/18', '02:02', 'Nupur', 'ab lag raha hai ameer ladka bola'),
#  ('21/01/18',
#   '02:02',
#   'Vaibhav Tripathi',
#   'Nhi be. Sandals pehen k mere pair multi colored ho gye h'),
#  ('21/01/18', '02:02', 'Vaibhav Tripathi', '\xf0\x9f\x98\x86'),
#  ('21/01/18', '02:02', 'Nupur', 'gym wale joote bahar q nahi pehen sakte?'),
#  ('21/01/18',
#   '02:03',
#   'Vaibhav Tripathi',
#   'Fir wo gnde ho jaenge. Gym me allow nhi krenge unhe'),
#  ('21/01/18',
#   '02:03',
#   'Vaibhav Tripathi',
#   'Wo machines pe chdhte h na usko pehen k'),
#  ('21/01/18', '02:03', 'Vaibhav Tripathi', 'To ekdum saaf hone chahiye'),
#  ('21/01/18',
#   '02:03',
#   'Vaibhav Tripathi',
#   'Aur wo bde sste wale liye the bs isi kam k liye'),
#  ('21/01/18',
#   '02:04',
#   'Nupur',
#   'pehle toh tumne kaha tha ki kuch bola nahi hai waha pe'),
#  ('21/01/18',
#   '02:05',
#   'Nupur',
#   'humne hi kaha tha ki alag se le jana hota hai'),
#  ('21/01/18',
#   '02:05',
#   'Vaibhav Tripathi',
#   'Haan usne abhi tk kuch nhi bola. Par notice lgi h jagah jagah'),
#  ('21/01/18', '02:05', 'Vaibhav Tripathi', 'Isliye hum pehle hi le liye'),
#  ('21/01/18',
#   '02:06',
#   'Nupur',
#   'hmm waise joota thoda saf krke bhi le ja sakte ho itna nahi pata chalega'),
#  ('21/01/18', '02:06', 'Nupur', 'lekin agar wo acche wale nahi hai'),
#  ('21/01/18', '02:06', 'Vaibhav Tripathi', 'Are wo nhi \xf0\x9f\x98\x95'),
#  ('21/01/18', '02:06', 'Vaibhav Tripathi', 'Wo bekar h'),
#  ('21/01/18', '02:06', 'Vaibhav Tripathi', 'Whi k liye shi h'),
#  ('21/01/18', '02:06', 'Nupur', 'thek hai'),
#  ('21/01/18', '02:07', 'Vaibhav Tripathi', 'Haan \xf0\x9f\x98\x8a'),
#  ('21/01/18', '02:07', 'Nupur', 'tum jaa ke check kroge kya shop pe?'),
#  ('21/01/18', '02:07', 'Nupur', 'pehn ke'),
#  ('21/01/18', '02:07', 'Nupur', 'kyuki oln bata nahi sakte comfort'),
#  ('21/01/18', '02:08', 'Nupur', 'size kya h?'),
#  ('21/01/18', '02:08', 'Vaibhav Tripathi', 'US 10, UK 9'),
#  ('21/01/18', '02:09', 'Nupur', '<Media omitted>'),
#  ('21/01/18', '02:09', 'Nupur', '<Media omitted>'),
#  ('21/01/18', '02:10', 'Vaibhav Tripathi', 'Blue wala acha h. Order kr de?'),
#  ('21/01/18', '02:10', 'Nupur', '<Media omitted>'),
#  ('21/01/18', '02:11', 'Nupur', 'abe ruko toh'),
#  ('21/01/18', '02:11', 'Vaibhav Tripathi', 'Acha theek'),
#  ('21/01/18',
#   '02:12',
#   'Nupur',
#   'hum na aise sirf design hi choose kar sakte hai'),
#  ('21/01/18', '02:12', 'Nupur', 'comfort nahi'),
#  ('21/01/18',
#   '02:13',
#   'Vaibhav Tripathi',
#   'Yar agar size theek h to comfort ho jaega branded me to'),
#  ('21/01/18', '02:13', 'Nupur', '<Media omitted>'),
#  ('21/01/18', '02:13', 'Vaibhav Tripathi', 'Shoes me utni dikkt nhi h'),
#  ('21/01/18', '02:13', 'Vaibhav Tripathi', 'Hume blue wala hi acha lg rha'),
#  ('21/01/18', '02:13', 'Vaibhav Tripathi', 'Simple h na'),
#  ('21/01/18', '02:14', 'Nupur', '<Media omitted>'),
#  ('21/01/18', '02:14', 'Vaibhav Tripathi', 'Han ye bhi acha h'),
#  ('21/01/18', '02:15', 'Nupur', 'secnd last??'),
#  ('21/01/18',
#   '02:15',
#   'Vaibhav Tripathi',
#   'Nhi. Wo thoda zyada fashionable lg rha hume'),
#  ('21/01/18',
#   '02:16',
#   'Vaibhav Tripathi',
#   'Aur usme yellow laces h \xf0\x9f\x98\x9e'),
#  ('21/01/18', '02:18', 'Nupur', '<Media omitted>'),
#  ('21/01/18', '02:19', 'Vaibhav Tripathi', 'A ye acha h \xf0\x9f\x98\x8a'),
#  ('21/01/18', '02:19', 'Vaibhav Tripathi', 'Fashionable h tbbhi'),
#  ('21/01/18', '02:20', 'Nupur', 'tumko koi tax nahi laga dega'),
#  ('21/01/18', '02:20', 'Nupur', 'par yeh 4200 ka hai'),
#  ('21/01/18', '02:20', 'Nupur', 'par tum toh ameer launde ho'),
#  ('21/01/18', '02:20', 'Nupur', '\xf0\x9f\x98\x9b\xf0\x9f\x98\x9b'),
#  ('21/01/18',
#   '02:20',
#   'Vaibhav Tripathi',
#   'Theek h wo to. Joote to thode mehenge chlte h'),
#  ('21/01/18', '02:20', 'Vaibhav Tripathi', '\xf0\x9f\x98\x8a'),
#  ('21/01/18', '02:21', 'Nupur', 'arey aur kya'),
#  ('21/01/18', '02:21', 'Nupur', '<Media omitted>'),
#  ('21/01/18', '02:22', 'Vaibhav Tripathi', 'Upr wala hi \xf0\x9f\x98\x8a'),
#  ('21/01/18', '02:24', 'Vaibhav Tripathi', 'Nike me nhi ache lge tumko?'),
#  ('21/01/18', '02:24', 'Nupur', 'mix dekh rahe hai'),
#  ('21/01/18', '02:24', 'Vaibhav Tripathi', 'Theek h'),
#  ('21/01/18', '02:26', 'Nupur', '<Media omitted>'),
#  ('21/01/18', '02:26', 'Vaibhav Tripathi', 'Ye bhi acha'),
#  ('21/01/18', '02:27', 'Nupur', 'chlo hum link bhejte h'),
#  ('21/01/18', '02:27', 'Nupur', 'ab final krlo tum inme se hi'),
#  ('21/01/18', '02:28', 'Vaibhav Tripathi', '2,5,6,8 me se jo bolo'),
#  ('21/01/18',
#   '02:30',
#   'Vaibhav Tripathi',
#   'Inme se kisi ek ka link bhej do. Whi kr de rhe'),
#  ('21/01/18', '02:31', 'Nupur', 'yar link kaise bheje'),
#  ('21/01/18', '02:31', 'Nupur', '?'),
#  ('21/01/18', '02:31', 'Vaibhav Tripathi', 'Acha tum bta do kaun sa'),
#  ('21/01/18', '02:31', 'Vaibhav Tripathi', 'Hum dhund lnge'),
#  ('21/01/18', '02:33', 'Nupur', 'cart me dekho'),
#  ('21/01/18', '02:33', 'Nupur', 'add kar diya'),
#  ('21/01/18', '02:35', 'Vaibhav Tripathi', 'A tumne to sare kr diye'),
#  ('21/01/18', '02:35', 'Vaibhav Tripathi', 'Ab ek kam aur kro'),
#  ('21/01/18', '02:35', 'Vaibhav Tripathi', 'Isme se 4 hata do'),
#  ('21/01/18', '02:35', 'Vaibhav Tripathi', '\xf0\x9f\x98\x8a'),
#  ('21/01/18', '02:35', 'Nupur', 'hehehe'),
#  ('21/01/18', '02:35', 'Nupur', 'khud se select kro'),
#  ('21/01/18', '02:35', 'Vaibhav Tripathi', 'Are humne ek level select kiya'),
#  ('21/01/18', '02:35', 'Vaibhav Tripathi', 'Ab tumhari baari'),
#  ('21/01/18', '02:36', 'Nupur', 'ek hata diya humne'),
#  ('21/01/18', '02:36', 'Vaibhav Tripathi', 'Hehe ye acha h'),
#  ('21/01/18', '02:36', 'Nupur', 'tum ab'),
#  ('21/01/18', '02:36', 'Vaibhav Tripathi', 'Kr diya'),
#  ('21/01/18', '02:36', 'Nupur', '4 hi dikh rahe'),
#  ('21/01/18', '02:37', 'Vaibhav Tripathi', 'Han ab ho gya'),
#  ('21/01/18', '02:38', 'Nupur', 'hata diya'),
#  ('21/01/18', '02:38', 'Vaibhav Tripathi', 'Yar ye glt h ab'),
#  ('21/01/18', '02:38', 'Nupur', '\xf0\x9f\x98\x86\xf0\x9f\x98\x86'),
#  ('21/01/18', '02:38', 'Nupur', 'kya'),
#  ('21/01/18', '02:39', 'Vaibhav Tripathi', 'Last humpe a gya'),
#  ('21/01/18', '02:39', 'Vaibhav Tripathi', 'Tumhe 6 add krne the'),
#  ('21/01/18', '02:39', 'Vaibhav Tripathi', '\xf0\x9f\x98\x9b'),
#  ('21/01/18', '02:39', 'Nupur', 'humne blck wala hataya h'),
#  ('21/01/18', '02:39', 'Nupur', 'tmko nhi chaiye wo?'),
#  ('21/01/18', '02:40', 'Vaibhav Tripathi', 'Nhi aisa nhi h'),
#  ('21/01/18', '02:40', 'Vaibhav Tripathi', 'Ab sirf do bche na'),
#  ('21/01/18', '02:40', 'Vaibhav Tripathi', 'Blue dono'),
#  ('21/01/18', '02:41', 'Nupur', 'humne wo black wali isliye hatai thi'),
#  ('21/01/18', '02:41', 'Vaibhav Tripathi', 'Ab?'),
#  ('21/01/18',
#   '02:42',
#   'Nupur',
#   'tum bolo tmko kaisa lag raha hai ... black wali eliminate krne k bad?'),
#  ('21/01/18',
#   '02:42',
#   'Vaibhav Tripathi',
#   'Are theek h wo to. Jitne add hue the sb shi the. Koi bhi a jae'),
#  ('21/01/18', '02:43', 'Vaibhav Tripathi', 'Ab in dono me se kya krna h'),
#  ('21/01/18',
#   '02:44',
#   'Vaibhav Tripathi',
#   '\xe2\x9c\x8c\xf0\x9f\x8f\xbbChlo choose a finger \xf0\x9f\x98\x9b'),
#  ('21/01/18', '02:44', 'Vaibhav Tripathi', 'Left ya right'),
#  ('21/01/18', '02:44', 'Nupur', 'black wala'),
#  ('21/01/18', '02:44', 'Nupur', '\xf0\x9f\x98\x9b\xf0\x9f\x98\x9b'),
#  ('21/01/18', '02:44', 'Vaibhav Tripathi', 'Hehehe'),
#  ('21/01/18', '02:44', 'Vaibhav Tripathi', 'Theek'),
#  ('21/01/18', '02:44', 'Vaibhav Tripathi', 'Use add krdo vapas'),
#  ('21/01/18', '02:46', 'Vaibhav Tripathi', 'Bs ab kr rhe order'),
#  ('21/01/18', '02:46', 'Vaibhav Tripathi', '\xf0\x9f\x98\x8a'),
#  ('21/01/18', '02:46', 'Nupur', 'tm choose krlo'),
#  ('21/01/18', '02:46', 'Vaibhav Tripathi', 'Kr liya'),
#  ('21/01/18', '02:46', 'Nupur', 'abhi 2 h'),
#  ('21/01/18', '02:46', 'Nupur', 'dono mast'),
#  ('21/01/18', '02:46', 'Nupur', 'kuch bhi krlo'),
#  ('21/01/18', '02:46', 'Vaibhav Tripathi', 'Going with black'),
#  ('21/01/18', '02:48', 'Vaibhav Tripathi', 'Kl a bhi jaega'),
#  ('21/01/18', '02:48', 'Vaibhav Tripathi', '\xf0\x9f\x98\x8a'),
#  ('21/01/18', '02:51', 'Nupur', 'arey wah'),
#  ('21/01/18', '02:51', 'Nupur', 'mubarak ho'),
#  ('21/01/18', '02:51', 'Vaibhav Tripathi', 'Hehehe'),
#  ('21/01/18',
#   '02:52',
#   'Vaibhav Tripathi',
#   'Tumhe bhi. Itni mehnt humne kbhi nhi ki pehle joota lene me'),
#  ('21/01/18', '02:52', 'Nupur', 'sacchi kya?'),
#  ('21/01/18',
#   '02:53',
#   'Vaibhav Tripathi',
#   'Haan aj jb din me dekha tha to bs 5 min spend kiye hnge shayad. Usi me jo a gya psnd bs whi'),
#  ('21/01/18', '02:53', 'Vaibhav Tripathi', '\xf0\x9f\x98\x9b'),
#  ('21/01/18', '02:55', 'Nupur', 'badhiya'),
#  ('21/01/18',
#   '02:55',
#   'Nupur',
#   'meri behen hai ek ... wo 2-3 mahina dekhti hai'),
#  ('21/01/18', '02:56', 'Vaibhav Tripathi', 'Hehehe'),
#  ('21/01/18', '02:56', 'Vaibhav Tripathi', 'Yar patience h lekin'),
#  ('21/01/18', '02:56', 'Vaibhav Tripathi', 'Abhi mn kr rha h kuch pehenne ka'),
#  ('21/01/18', '02:56', 'Nupur', 'boht'),
#  ('21/01/18', '02:56', 'Vaibhav Tripathi', 'Kaise koi wait kr skta h itna'),
#  ('21/01/18', '02:57', 'Nupur', 'yar wo ajeeb hi h'),
#  ('21/01/18', '02:57', 'Nupur', 'leti hi nahi saman'),
#  ('21/01/18',
#   '02:57',
#   'Nupur',
#   'lene k bad bhi sochti rehti h ki galat toh nahi le liya'),
#  ('21/01/18', '02:57', 'Nupur', 'isliye humne aaj order kr diye'),
#  ('21/01/18', '02:57', 'Nupur', 'usse hote nahi'),
#  ('21/01/18', '02:57', 'Vaibhav Tripathi', 'Acha jiska bday h'),
#  ('21/01/18', '02:58', 'Nupur', 'ha'),
#  ('21/01/18', '02:58', 'Nupur', 'wahi'),
#  ('21/01/18', '02:58', 'Vaibhav Tripathi', 'Hehe shi kiya ekdum'),
#  ('21/01/18', '02:58', 'Nupur', 'fir uske bad bhi 2-3 foto bhej rahi'),
#  ('21/01/18', '02:58', 'Nupur', 'ki change kara le kya'),
#  ('21/01/18',
#   '02:58',
#   'Vaibhav Tripathi',
#   '\xf0\x9f\xa4\xa6\xf0\x9f\x8f\xbb\xe2\x80\x8d\xe2\x99\x82'),
#  ('21/01/18', '02:58', 'Nupur', 'aur ek tum ho'),
#  ('21/01/18', '02:59', 'Nupur', 'khel khel me final'),
#  ('21/01/18',
#   '02:59',
#   'Vaibhav Tripathi',
#   'Are itna kya serious hona usme. Pehli bat to agar ekdum hi kuch glt a gya to return ki facility h'),
#  ('21/01/18', '02:59', 'Vaibhav Tripathi', 'Aur wo na bhi ho'),
#  ('21/01/18', '02:59', 'Vaibhav Tripathi', 'To ek sal me fir mauka milega'),
#  ('21/01/18', '02:59', 'Vaibhav Tripathi', '\xf0\x9f\x98\x9b'),
#  ('21/01/18',
#   '03:00',
#   'Vaibhav Tripathi',
#   'Sochne me 2-3 mahine bitana to definitely ghate ka sauda h'),
#  ('21/01/18', '03:00', 'Nupur', 'hehe abe kaun samjhaye'),
#  ('21/01/18', '03:00', 'Nupur', 'pata kya ek cup set lena tha'),
#  ('21/01/18', '03:00', 'Nupur', '150 rs ka tha'),
#  ('21/01/18', '03:01', 'Nupur', 'poora aminabad ghumai'),
#  ('21/01/18', '03:01', 'Nupur', '2 din'),
#  ('21/01/18', '03:01', 'Nupur', 'tb jaake li'),
#  ('21/01/18',
#   '03:01',
#   'Nupur',
#   'lene ke bad fir jaa rahi dukan change karane'),
#  ('21/01/18', '03:01', 'Nupur', 'hum aur mummy chale aaye chod k wahi'),
#  ('21/01/18', '03:02', 'Vaibhav Tripathi', '\xf0\x9f\x98\x86'),
#  ('21/01/18', '03:02', 'Vaibhav Tripathi', 'Abe yaaar'),
#  ('21/01/18',
#   '03:03',
#   'Vaibhav Tripathi',
#   'A dd ki ek friend ki story btaye the ameenabad wali?'),
#  ('21/01/18', '03:03', 'Nupur', 'nahi'),
#  ('21/01/18',
#   '03:03',
#   'Vaibhav Tripathi',
#   'Yar wo bda hi ajeeb btayi dd. Uski ek friend h aksar use ameenabad le jati thi. Whan jake mostly wo bs dekhti thi lati kbhi kuch thi nhi'),
#  ('21/01/18',
#   '03:04',
#   'Vaibhav Tripathi',
#   'Lekin dd apne liye kuch le leti thi to she was still fine'),
#  ('21/01/18',
#   '03:04',
#   'Vaibhav Tripathi',
#   'Ek br dd dekhi vaaps ate tym ki wo jo friend h na wo kuch nyi chhodiyan pehni h jo usi din un logo ne shop me dekhi thi'),
#  ('21/01/18', '03:05', 'Vaibhav Tripathi', 'Aur try ki thi'),
#  ('21/01/18',
#   '03:05',
#   'Vaibhav Tripathi',
#   'To dd ne unse bola ki ye glti se apke hath me reh gyi shayad'),
#  ('21/01/18',
#   '03:06',
#   'Vaibhav Tripathi',
#   'To wo log na zyada dur nhi nikle the'),
#  ('21/01/18', '03:06', 'Vaibhav Tripathi', 'Tbbhi wo kehti h koi bt nhi'),
#  ('21/01/18', '03:06', 'Vaibhav Tripathi', 'Aj ghr chlte h der ho gyi'),
#  ('21/01/18', '03:06', 'Nupur', 'hawww'),
#  ('21/01/18', '03:06', 'Vaibhav Tripathi', 'Hum kl ake wapas kr denge'),
#  ('21/01/18', '03:06', 'Nupur', 'muslim thi?'),
#  ('21/01/18',
#   '03:06',
#   'Vaibhav Tripathi',
#   'To dd smjh gyi ki ye kabhi kuch purchase q nhi krti'),
#  ('21/01/18', '03:06', 'Vaibhav Tripathi', 'Nhi be'),
#  ('21/01/18', '03:06', 'Nupur', 'hehehe'),
#  ('21/01/18', '03:07', 'Vaibhav Tripathi', 'Humare mohalle ki h'),
#  ('21/01/18', '03:07', 'Vaibhav Tripathi', 'Bdi h'),
#  ('21/01/18', '03:07', 'Vaibhav Tripathi', 'Shadi bhi ho gyi ab to'),
#  ('21/01/18', '03:07', 'Nupur', 'badhiya ladki h'),
#  ('21/01/18', '03:07', 'Vaibhav Tripathi', 'Are bdhiya kya'),
#  ('21/01/18',
#   '03:07',
#   'Vaibhav Tripathi',
#   'Humne dd se kaha ki kabhi jana nhi agli br se'),
#  ('21/01/18',
#   '03:07',
#   'Vaibhav Tripathi',
#   'Agar pkdi gyi to zamanat krane aenge nhi'),
#  ('21/01/18', '03:07', 'Nupur', 'sahi me'),
#  ('21/01/18', '03:07', 'Vaibhav Tripathi', '\xf0\x9f\x98\x9b'),
#  ('21/01/18', '03:07', 'Nupur', 'hehehe'),
#  ('21/01/18', '03:08', 'Nupur', 'pakdi jaye toh kitni bejjati hogi'),
#  ('21/01/18', '03:08', 'Vaibhav Tripathi', 'Han be socho'),
#  ('21/01/18', '03:08', 'Vaibhav Tripathi', 'Bde himmti log hote h'),
#  ('21/01/18',
#   '03:09',
#   'Vaibhav Tripathi',
#   'Aur dd ko keh rhi thi ki hath ki safai manni pdegi uski'),
#  ('21/01/18', '03:09', 'Vaibhav Tripathi', '\xf0\x9f\x98\x9b'),
#  ('21/01/18',
#   '03:09',
#   'Vaibhav Tripathi',
#   'Dukan pr to hume bhi pta nhi chala ki kb rkhi usne'),
#  ('21/01/18', '03:10', 'Nupur', 'hume tbhi laga burkhe wali hogi'),
#  ('21/01/18', '03:10', 'Vaibhav Tripathi', 'Are without burkha'),
#  ('21/01/18', '03:10', 'Vaibhav Tripathi', 'Tez ldki h'),
#  ('21/01/18', '03:10', 'Vaibhav Tripathi', '\xf0\x9f\x98\x8e'),
#  ('21/01/18', '03:10', 'Nupur', 'sai me'),
#  ('21/01/18', '03:10', 'Vaibhav Tripathi', "She doesn't need a cover"),
#  ('21/01/18', '03:10', 'Nupur', '\xf0\x9f\x91\x8f\xf0\x9f\x8f\xbb'),
#  ('21/01/18', '03:10', 'Nupur', 'hehehe'),
#  ('21/01/18', '03:11', 'Nupur', 'a neend lag rhi'),
#  ('21/01/18', '03:11', 'Vaibhav Tripathi', 'Acha theek h'),
#  ('21/01/18', '03:11', 'Vaibhav Tripathi', '\xf0\x9f\x98\x8a'),
#  ('21/01/18', '03:11', 'Vaibhav Tripathi', 'Sote h'),
#  ('21/01/18', '03:11', 'Nupur', 'ha'),
#  ('21/01/18', '03:11', 'Vaibhav Tripathi', 'Sath me'),
#  ('21/01/18', '03:11', 'Nupur', 'jldi uthna kal'),
#  ('21/01/18', '03:11', 'Vaibhav Tripathi', '\xf0\x9f\x98\x8c'),
#  ('21/01/18', '03:11', 'Nupur', 'ha'),
#  ('21/01/18', '03:11', 'Nupur', '\xf0\x9f\x98\x8a\xf0\x9f\x98\x8a'),
#  ('21/01/18', '03:11', 'Vaibhav Tripathi', 'Kyun?'),
#  ('21/01/18', '03:12', 'Nupur', 'aise hi'),
#  ('21/01/18', '03:12', 'Nupur', 'utkarsh bolke gaya h yaha pe sabko'),
#  ('21/01/18', '03:12', 'Nupur', 'ki 10 bje utha dega'),
#  ('21/01/18', '03:12', 'Nupur', 'toh hum tmhe bhi bolre h'),
#  ('21/01/18', '03:12', 'Nupur', '\xf0\x9f\x98\x9b\xf0\x9f\x98\x9b'),
#  ('21/01/18', '03:12', 'Vaibhav Tripathi', 'Hehehe acha'),
#  ('21/01/18',
#   '03:12',
#   'Vaibhav Tripathi',
#   'Han 10 pe to hum bhi utha die jaenge yhn'),
#  ('21/01/18', '03:13', 'Nupur', 'bas sahi hai'),
#  ('21/01/18', '03:13', 'Nupur', 'so jate hai jldi se'),
#  ('21/01/18', '03:13', 'Vaibhav Tripathi', 'Theek h'),
#  ('21/01/18', '03:13', 'Nupur', 'byeee'),
#  ('21/01/18', '03:13', 'Vaibhav Tripathi', 'Bye Nupurrr'),
#  ('21/01/18', '03:13', 'Nupur', '\xf0\x9f\x98\x8a\xf0\x9f\x98\x8a'),
#  ('21/01/18', '03:13', 'Nupur', 'gn sd tc'),
#  ('21/01/18', '03:14', 'Vaibhav Tripathi', 'Gn sd \xe2\x98\xba'),
#  ('21/01/18', '03:14', 'Vaibhav Tripathi', 'Girna nhi'),
#  ('21/01/18', '03:14', 'Nupur', 'okk'),
#  ('21/01/18', '03:14', 'Nupur', 'tum bhi'),
#  ('21/01/18', '03:14', 'Vaibhav Tripathi', 'Haan theek'),
#  ('21/01/18', '03:14', 'Vaibhav Tripathi', 'Aur e beta ko sula lena paas me'),
#  ('21/01/18', '03:14', 'Vaibhav Tripathi', '\xe2\x98\xba'),
#  ('21/01/18', '03:14', 'Nupur', 'ha sath me hai'),
#  ('21/01/18', '03:14', 'Vaibhav Tripathi', 'Bdhiya'),
#  ('21/01/18', '03:15', 'Vaibhav Tripathi', 'Chlo byeee'),
#  ('21/01/18', '03:15', 'Vaibhav Tripathi', '\xe2\x9d\xa4'),
#  ('21/01/18', '03:15', 'Nupur', 'byee'),
#  ('21/01/18', '03:15', 'Nupur', '\xe2\x9d\xa4'),
#  ('21/01/18', '12:45', 'Vaibhav Tripathi', 'Suprabhaat!'),
#  ('21/01/18', '12:45', 'Vaibhav Tripathi', '\xf0\x9f\x98\x8a'),
#  ('21/01/18', '12:49', 'Nupur', 'sudopahar'),
#  ('21/01/18', '12:59', 'Vaibhav Tripathi', 'Hehehe'),
#  ('21/01/18', '13:00', 'Vaibhav Tripathi', 'Kya kr rhi?'),
#  ('21/01/18', '14:03', 'Nupur', 'khana bana diya'),
#  ('21/01/18', '14:03', 'Nupur', 'bhaiya gola maare'),
#  ('21/01/18', '14:19', 'Vaibhav Tripathi', 'Kya bnaya?'),
#  ('21/01/18', '18:08', 'Nupur', 'aloo baigan'),
#  ('21/01/18', '18:08', 'Nupur', 'roti'),
#  ('21/01/18', '19:01', 'Vaibhav Tripathi', 'Bdhiya'),
#  ('21/01/18', '19:01', 'Vaibhav Tripathi', 'Humne poha bnaya din me'),
#  ('21/01/18', '21:39', 'Nupur', 'arey wah'),
#  ('21/01/18', '21:39', 'Nupur', 'tum aaj kaha par ho??'),
#  ('21/01/18', '21:39', 'Vaibhav Tripathi', 'Kormangala me ae h'),
#  ('21/01/18', '21:39', 'Vaibhav Tripathi', 'Mtech wale paancho h aaj'),
#  ('21/01/18', '21:39', 'Vaibhav Tripathi', 'Tum btao'),
#  ('21/01/18', '21:40', 'Nupur', 'arey wah'),
#  ('21/01/18', '21:40', 'Nupur', 'apne ghar pe ya kahi aur?'),
#  ('21/01/18', '21:40', 'Vaibhav Tripathi', 'Bahar ae khane'),
#  ('21/01/18', '21:41', 'Nupur', 'aaj hum log bhi jaane wale the'),
# ...
#  ('21/01/18', '22:33', 'Vaibhav Tripathi', 'Chhota h'),
#  ('21/01/18', '22:33', 'Vaibhav Tripathi', 'Pr live music acha hota h whaan'),
#  ('21/01/18', '22:47', 'Nupur', 'okkk'),
#  ('21/01/18', '22:47', 'Nupur', 'yar aaj firse mera code fas raha hai'),
#  ('21/01/18', '22:47', 'Nupur', '\xf0\x9f\x98\x94\xf0\x9f\x98\x94'),
#  ('21/01/18', '23:37', 'Vaibhav Tripathi', 'Arey \xf0\x9f\x98\x9e'),
#  ('21/01/18',
#   '23:37',
#   'Vaibhav Tripathi',
#   'Acha hum free ho the thodi der me'),
#  ('21/01/18', '23:37', 'Vaibhav Tripathi', 'Fir sath me dekhte h'),
#  ('21/01/18', '23:37', 'Vaibhav Tripathi', '\xf0\x9f\x98\x8a'),
#  ('21/01/18', '23:56', 'Nupur', 'theek'),
#  ('21/01/18', '23:56', 'Nupur', '\xf0\x9f\x98\x8a'),
#  ('22/01/18', '00:19', 'Vaibhav Tripathi', 'Chla?'),
#  ('22/01/18', '00:51', 'Nupur', 'nhi'),
#  ('22/01/18', '00:51', 'Nupur', 'tum??'),
#  ('22/01/18', '00:52', 'Vaibhav Tripathi', 'Hum let gye'),
#  ('22/01/18', '00:52', 'Vaibhav Tripathi', '\xf0\x9f\x98\x8a'),
#  ('22/01/18', '00:52', 'Nupur', 'kiske sath?'),
#  ('22/01/18', '00:52', 'Nupur', '\xf0\x9f\x98\x9b'),
#  ('22/01/18',
#   '00:52',
#   'Vaibhav Tripathi',
#   'Hehe aaj humare room me shi me ldka h'),
#  ('22/01/18', '00:52', 'Vaibhav Tripathi', 'Lekin hum ekdum door h'),
#  ('22/01/18', '00:52', 'Vaibhav Tripathi', '\xf0\x9f\x98\x9b'),
#  ('22/01/18', '00:53', 'Vaibhav Tripathi', 'Sath me bilkul nhi'),
#  ('22/01/18', '00:53', 'Nupur', 'kon ladka'),
#  ('22/01/18', '00:53', 'Vaibhav Tripathi', 'Bhushan'),
#  ('22/01/18', '00:53', 'Nupur', 'uske opar nahi chadhte'),
#  ('22/01/18', '00:53', 'Vaibhav Tripathi', 'Bilkul nhi'),
#  ('22/01/18', '00:54', 'Vaibhav Tripathi', 'Wo equation bs Mohini k sath h'),
#  ('22/01/18', '00:54', 'Vaibhav Tripathi', '\xf0\x9f\x98\x86'),
#  ('22/01/18', '00:55', 'Vaibhav Tripathi', 'Tum kya kr rhi ho?'),
#  ('22/01/18', '00:55', 'Nupur', 'hum mahabharat dekh rahe the'),
#  ('22/01/18', '00:55', 'Nupur', 'sabko dekhna tha'),
#  ('22/01/18', '00:55', 'Vaibhav Tripathi', 'Hehe'),
#  ('22/01/18', '00:55', 'Vaibhav Tripathi', 'Ye kahan se aya sbko aaj?'),
#  ('22/01/18', '00:55', 'Nupur', 'palace of illusions'),
#  ('22/01/18', '00:56', 'Nupur', 'book padh ri kriti yeh wali'),
#  ('22/01/18', '00:56', 'Nupur', 'yeh draupadi ke bare me hai'),
#  ('22/01/18', '00:56', 'Nupur', 'toh wahi bat chal rahi thi'),
#  ('22/01/18', '00:56', 'Vaibhav Tripathi', 'Ohh'),
#  ('22/01/18', '00:56', 'Vaibhav Tripathi', 'Kya bat kr rhe the?'),
#  ('22/01/18',
#   '00:57',
#   'Nupur',
#   'usme likha h ki draupadi kisi pandit se bhavishya poochti h'),
#  ('22/01/18',
#   '00:57',
#   'Nupur',
#   'wo bata deta h tmhari wajah se boht bura hoga'),
#  ('22/01/18', '00:58', 'Nupur', 'toh wo pochti h kaise change kr sakte h'),
#  ('22/01/18',
#   '00:58',
#   'Nupur',
#   'wo kehta h change nahi ho sakta lekin 3 cheje krna'),
#  ('22/01/18', '00:58', 'Nupur', 'shadi se pehle pati se question'),
#  ('22/01/18', '00:59', 'Nupur', 'question control karna'),
#  ('22/01/18', '00:59', 'Nupur', 'aisa kuch'),
#  ('22/01/18',
#   '00:59',
#   'Nupur',
#   'fir jb pati k pas power ho toh laughter pe cntrl krna'),
#  ('22/01/18',
#   '01:00',
#   'Nupur',
#   'aur jb bohot hi buri state ho tumhari toh curse krne pe cntrl'),
#  ('22/01/18', '01:00', 'Vaibhav Tripathi', 'Ohhh'),
#  ('22/01/18',
#   '01:00',
#   'Vaibhav Tripathi',
#   'Ladki sb ki mtlb jo mana kiya gaya'),
#  ('22/01/18', '01:00', 'Nupur', 'abhi first wala nahi samajh a raha'),
#  ('22/01/18', '01:01', 'Vaibhav Tripathi', 'Han be'),
#  ('22/01/18',
#   '01:02',
#   'Vaibhav Tripathi',
#   'Swayamvar k pehle to wo kuch nhi poochi thi'),
#  ('22/01/18', '01:02', 'Vaibhav Tripathi', 'Bad me shayad kuch hua ho'),
#  ('22/01/18', '01:02', 'Nupur', 'wahi kuch tha'),
#  ('22/01/18', '01:03', 'Vaibhav Tripathi', 'Vaise jo nya wala Mahabharat tha'),
#  ('22/01/18', '01:03', 'Vaibhav Tripathi', 'Usne second wala nhi dikhaya h'),
#  ('22/01/18',
#   '01:03',
#   'Vaibhav Tripathi',
#   'Usme aise dikhaya h ki draupadi nhi hasi thi'),
#  ('22/01/18',
#   '01:04',
#   'Vaibhav Tripathi',
#   'Duryodhan ko confusion ho gyi thi'),
#  ('22/01/18', '01:04', 'Nupur', 'wo pora usko acha potray kr rahe honge'),
#  ('22/01/18', '01:04', 'Vaibhav Tripathi', 'Haan whi'),
#  ('22/01/18', '01:04', 'Vaibhav Tripathi', 'Baki humne jahan bhi pdha h'),
#  ('22/01/18', '01:04', 'Vaibhav Tripathi', 'Usme to bola h ki wo hasi thi'),
#  ('22/01/18', '01:04', 'Vaibhav Tripathi', 'Bhut zor se'),
#  ('22/01/18', '01:04', 'Vaibhav Tripathi', '\xf0\x9f\x98\x9b'),
#  ('22/01/18', '01:06', 'Nupur', 'hehehehe'),
#  ('22/01/18', '01:06', 'Nupur', 'tum itta kahe khush ho'),
#  ('22/01/18', '01:07', 'Vaibhav Tripathi', 'Aise hi'),
#  ('22/01/18',
#   '01:07',
#   'Vaibhav Tripathi',
#   'Tum kaun sa part dekh rhi fir mahabharat me?'),
#  ('22/01/18', '01:12', 'Nupur', '<Media omitted>'),
#  ('22/01/18',
#   '01:14',
#   'Vaibhav Tripathi',
#   'Kuch error h kya? Python me variable declare krte nhi usually'),
#  ('22/01/18', '01:14', 'Vaibhav Tripathi', 'Seedhe initialize hi hote h'),
#  ('22/01/18', '01:15', 'Vaibhav Tripathi', 'Acha smjhe'),
#  ('22/01/18', '01:15', 'Vaibhav Tripathi', '[] ki jagah {} likh do'),
#  ('22/01/18', '01:16', 'Vaibhav Tripathi', 'Wo dictionary h naa'),
#  ('22/01/18', '01:16', 'Nupur', 'nahi'),
#  ('22/01/18',
#   '01:16',
#   'Nupur',
#   'yar actually hum na usko dosre method me call kar rahe hai'),
#  ('22/01/18', '01:16', 'Nupur', 'toh ho nahi raha'),
#  ('22/01/18', '01:17', 'Nupur', 'kyuki usse for loop ke andar use kiya h'),
#  ('22/01/18', '01:18', 'Nupur', 'scope utna hi rhega na fir??'),
#  ('22/01/18', '01:18', 'Nupur', 'if pehle declare nahi kar rahe'),
#  ('22/01/18', '01:19', 'Vaibhav Tripathi', 'Yar for k upr declare kiya h'),
#  ('22/01/18',
#   '01:19',
#   'Vaibhav Tripathi',
#   'To for k andr use kr skte h na fir'),
#  ('22/01/18', '01:19', 'Nupur', 'in case hum uske opar declare nahi kar rahe'),
#  ('22/01/18',
#   '01:20',
#   'Vaibhav Tripathi',
#   'To fir use index krke access nhi kro'),
#  ('22/01/18', '01:20', 'Vaibhav Tripathi', 'Append use kro'),
#  ('22/01/18', '01:21', 'Nupur', 'abe yeh bada natak lag raha'),
#  ('22/01/18', '01:22', 'Nupur', 'append nahi lagane ka man h'),
#  ('22/01/18', '01:22', 'Nupur', 'kuch aur batao'),
#  ('22/01/18', '01:24', 'Vaibhav Tripathi', '<Media omitted>'),
#  ('22/01/18',
#   '01:24',
#   'Vaibhav Tripathi',
#   'Dekho empty array ko with index nhi access kr skte'),
#  ('22/01/18',
#   '01:24',
#   'Vaibhav Tripathi',
#   'To ya to pehle array ko kuch dummy values se initialize kro'),
#  ('22/01/18', '01:24', 'Vaibhav Tripathi', 'Lekin ye bhut clean nhi h'),
#  ('22/01/18', '01:24', 'Vaibhav Tripathi', 'Append better h'),
#  ('22/01/18', '01:28', 'Vaibhav Tripathi', '<Media omitted>'),
#  ('22/01/18', '01:30', 'Nupur', 'yar humko nahi aa raha samjh me'),
#  ('22/01/18', '01:31', 'Vaibhav Tripathi', 'Acha error btao kya a rhi h'),
#  ('22/01/18', '01:31', 'Nupur', 'wahi na index wali'),
#  ('22/01/18', '01:31', 'Nupur', 'kuch dynamic nahi ho sakta hai?'),
#  ('22/01/18', '01:32', 'Vaibhav Tripathi', 'Append se hoga na'),
#  ('22/01/18', '01:32', 'Vaibhav Tripathi', 'Bhut zra sa change to h'),
#  ('22/01/18', '01:32', 'Vaibhav Tripathi', 'Kr ke dekh lo ek br jldi se'),
#  ('22/01/18', '01:32', 'Nupur', 'ab humne laptop rakh diya hai'),
#  ('22/01/18', '01:32', 'Nupur', 'lekin kal ofc jake try krenge append wala'),
#  ('22/01/18', '01:32', 'Nupur', '\xf0\x9f\x98\x8a'),
#  ('22/01/18', '01:32', 'Nupur', 'thank you'),
#  ('22/01/18',
#   '01:33',
#   'Vaibhav Tripathi',
#   'Haan index wala issue to bhut aram se solve hoga'),
#  ('22/01/18', '01:33', 'Vaibhav Tripathi', '\xf0\x9f\x98\x8a'),
#  ('22/01/18', '01:33', 'Vaibhav Tripathi', 'Aur btao'),
#  ('22/01/18', '01:36', 'Nupur', 'aurr'),
#  ('22/01/18', '01:36', 'Nupur', 'tm batao'),
#  ('22/01/18', '01:36', 'Vaibhav Tripathi', 'Kya kiya aaj?'),
#  ('22/01/18', '01:46', 'Nupur', 'yaad kiya tmko dher sara'),
#  ('22/01/18', '01:48', 'Vaibhav Tripathi', 'Awww'),
#  ('22/01/18', '01:48', 'Nupur', '\xe2\x98\xba\xe2\x98\xba'),
#  ('22/01/18', '01:48', 'Vaibhav Tripathi', '\xe2\x9d\xa4'),
#  ('22/01/18', '01:48', 'Nupur', 'hehe hum toh flirt kr re the'),
#  ('22/01/18', '01:48', 'Nupur', 'tum sach maan gaye??'),
#  ('22/01/18', '01:48', 'Nupur', '\xf0\x9f\x98\x9b'),
#  ('22/01/18', '01:49', 'Vaibhav Tripathi', 'Ohh'),
#  ('22/01/18', '01:49', 'Vaibhav Tripathi', '\xf0\x9f\x98\x8f'),
#  ('22/01/18', '01:49', 'Vaibhav Tripathi', 'Ctrl Z \xf0\x9f\x98\x94'),
#  ('22/01/18', '01:49', 'Nupur', 'hehehe'),
#  ('22/01/18', '01:50', 'Nupur', '\xf0\x9f\x98\x9d\xf0\x9f\x98\x9d'),
#  ('22/01/18', '01:50', 'Nupur', 'tumne kya kiya aaj'),
#  ('22/01/18',
#   '01:50',
#   'Vaibhav Tripathi',
#   'Ghr pe hi baithe h ldko k sath btiya rhe the'),
#  ('22/01/18', '01:50', 'Vaibhav Tripathi', '*the'),
#  ('22/01/18', '01:50', 'Nupur', 'bhk'),
#  ('22/01/18',
#   '01:51',
#   'Vaibhav Tripathi',
#   'Hum nhi bolenge sweet wala \xf0\x9f\x98\x92'),
#  ('22/01/18', '01:51', 'Vaibhav Tripathi', 'Tum mze leti ho humare'),
#  ('22/01/18', '01:51', 'Nupur', 'hehhe'),
#  ('22/01/18', '01:51', 'Nupur', '\xf0\x9f\x98\x82'),
#  ('22/01/18', '01:52', 'Nupur', 'accha nahi na'),
#  ('22/01/18', '01:52', 'Nupur', 'tm bhi le sakte ho'),
#  ('22/01/18', '01:52', 'Nupur', 'par seedhe mat bano maja nahi ati'),
#  ('22/01/18', '01:53', 'Vaibhav Tripathi', 'Hume nhi lena \xf0\x9f\x98\x94'),
#  ('22/01/18', '01:53', 'Nupur', 'q'),
#  ('22/01/18', '01:53', 'Nupur', 'ab tum aise boring nahi bana kro be'),
#  ('22/01/18', '01:53', 'Nupur', 'humko yahi bekar lagta h'),
#  ('22/01/18', '01:53', 'Nupur', 'pehle jaise raho na'),
#  ('22/01/18', '01:54', 'Vaibhav Tripathi', 'Acha theek'),
#  ('22/01/18', '01:54', 'Vaibhav Tripathi', 'Abse'),
#  ('22/01/18', '01:54', 'Vaibhav Tripathi', '\xf0\x9f\x98\x8a'),
#  ('22/01/18', '01:54', 'Nupur', 'kya kiya aaj?'),
#  ('22/01/18',
#   '01:55',
#   'Vaibhav Tripathi',
#   'Tera naam liya... Ooo... Tujhe yaad kiya \xf0\x9f\x8e\xbc'),
#  ('22/01/18', '01:55', 'Nupur', '\xf0\x9f\x98\x82'),
#  ('22/01/18', '01:55', 'Nupur', 'cheee'),
#  ('22/01/18', '01:55', 'Nupur', 'rehne do tum'),
#  ('22/01/18', '01:55', 'Vaibhav Tripathi', 'Kyaa'),
#  ('22/01/18', '01:55', 'Vaibhav Tripathi', 'Bdhiya to tha kitna'),
#  ('22/01/18', '01:56', 'Nupur', 'ha boht'),
#  ('22/01/18', '01:56', 'Nupur', 'sarla wed ko party de rahi h'),
#  ('22/01/18', '01:56', 'Nupur', '\xf0\x9f\x98\x8a'),
#  ('22/01/18', '01:56', 'Vaibhav Tripathi', 'Oh nice'),
#  ('22/01/18', '01:56', 'Vaibhav Tripathi', 'Kahan ja rhe?'),
#  ('22/01/18', '01:57', 'Nupur', 'truffles'),
#  ('22/01/18', '01:58', 'Nupur', '\xf0\x9f\x91\x8f\xf0\x9f\x8f\xbb'),
#  ('22/01/18', '01:58', 'Vaibhav Tripathi', 'Bdhiya'),
#  ('22/01/18', '01:58', 'Vaibhav Tripathi', '\xf0\x9f\x98\x8a'),
#  ('22/01/18',
#   '01:59',
#   'Vaibhav Tripathi',
#   'Bs khane ja rhe? No \xf0\x9f\x8d\xba??'),
#  ('22/01/18', '01:59', 'Nupur', 'yar daru toh dekha jayega'),
#  ('22/01/18', '01:59', 'Nupur', 'agar bana scene waisa toh'),
#  ('22/01/18', '01:59', 'Nupur', 'hum kriti utkarsh idhar se jayenge'),
#  ('22/01/18', '02:00', 'Vaibhav Tripathi', 'Acha'),
#  ('22/01/18',
#   '02:00',
#   'Vaibhav Tripathi',
#   'Shi group bn gya h tumhara \xf0\x9f\x98\x8a'),
#  ('22/01/18',
#   '02:01',
#   'Nupur',
#   'jyoti aaj na kriti se bolne lagi ki tm log ignore kr re ho just because i am going through depression'),
#  ('22/01/18', '02:01', 'Nupur', 'kyuki wo log humare sath rehte h'),
#  ('22/01/18', '02:01', 'Nupur', 'ladne lagi usse'),
#  ('22/01/18',
#   '02:01',
#   'Vaibhav Tripathi',
#   'To usne to ek nyi ldki bulayi h na'),
#  ('22/01/18', '02:02', 'Vaibhav Tripathi', 'Ab kya mtlb bolne ka'),
#  ('22/01/18', '02:02', 'Nupur', 'ha toh wo bhi humare sath rehti h'),
#  ('22/01/18', '02:02', 'Nupur', 'almost'),
#  ('22/01/18', '02:02', 'Nupur', 'usko bhi humare sath acha lagta h'),
#  ('22/01/18', '02:02', 'Nupur', 'aur waise toh yeh log jyoti ko bulate hai'),
#  ('22/01/18',
#   '02:03',
#   'Nupur',
#   'lekin agar hum hote hai toh wo chali jati hai'),
#  ('22/01/18', '02:03', 'Nupur', 'usko mere se dikkt hai'),
#  ('22/01/18', '02:03', 'Vaibhav Tripathi', 'Hmm'),
#  ('22/01/18',
#   '02:03',
#   'Vaibhav Tripathi',
#   'Yr itna kya bura maan gyi ab isme?'),
#  ('22/01/18', '02:04', 'Nupur', 'arey wo ajeeb h bohot'),
#  ('22/01/18', '02:04', 'Nupur', 'sabke bare me crib karti rehti hai'),
#  ('22/01/18', '02:04', 'Vaibhav Tripathi', 'Tumne uske bd se bt nhi ki usse?'),
#  ('22/01/18', '02:06', 'Nupur', 'nahii'),
#  ('22/01/18', '02:06', 'Nupur', 'bilkul bhi'),
#  ('22/01/18', '02:07', 'Vaibhav Tripathi', 'Haan theek hi h'),
#  ('22/01/18', '02:07', 'Nupur', 'ha be'),
#  ('22/01/18', '02:07', 'Nupur', 'hume sukoon hai'),
#  ('22/01/18', '02:07', 'Vaibhav Tripathi', 'Haan'),
#  ('22/01/18',
#   '02:08',
#   'Vaibhav Tripathi',
#   'Tumhara makeup ka saman bhi safe rhega \xf0\x9f\x98\x9b'),
#  ('22/01/18', '02:09', 'Nupur', 'wahi toh'),
#  ('22/01/18', '02:10', 'Vaibhav Tripathi', 'Wo abhi tk dawai le rhi h?'),
#  ('22/01/18', '02:10', 'Nupur', 'nahi shyad'),
#  ('22/01/18', '02:10', 'Nupur', 'abhi depression ka nahi pata kya scene h'),
#  ('22/01/18', '02:10', 'Nupur', 'lekin bitchin full on chalu hai'),
#  ('22/01/18', '02:11', 'Vaibhav Tripathi', 'Hehe'),
#  ('22/01/18',
#   '02:11',
#   'Vaibhav Tripathi',
#   'Yr depression theek h bhut hi valid h'),
#  ('22/01/18',
#   '02:11',
#   'Vaibhav Tripathi',
#   'Pr aisa behave to kro ki log support kre'),
#  ('22/01/18', '02:12', 'Nupur', 'hehe wahi be'),
#  ('22/01/18', '02:12', 'Nupur', 'is time kriti bhi chidhi hui hai'),
#  ('22/01/18',
#   '02:12',
#   'Nupur',
#   'because jbse utkarsh aaya h wo point out karta hi hai'),
#  ('22/01/18',
#   '02:13',
#   'Nupur',
#   'toh kriti ko bhi realise hota h ki wo galat kam karti hai'),
#  ('22/01/18',
#   '02:13',
#   'Nupur',
#   'plus uska rent wala uske dimag me full on bhara hai'),
#  ('22/01/18', '02:14', 'Vaibhav Tripathi', 'Rent wala kya?'),
#  ('22/01/18', '02:14', 'Nupur', 'kriti 12k deti hai'),
#  ('22/01/18', '02:15', 'Nupur', 'hum 8500 aur jyoti 8k'),
#  ('22/01/18',
#   '02:15',
#   'Nupur',
#   'toh utkarsh keh raha tha yeh galat distribution hai'),
#  ('22/01/18', '02:15', 'Nupur', 'rooms me itna fark nahi h'),
#  ('22/01/18', '02:15', 'Nupur', 'which is true'),
#  ('22/01/18', '02:16', 'Vaibhav Tripathi', 'Very true'),
#  ('22/01/18', '02:16', 'Nupur', 'toh usko bhi lagta hai'),
#  ('22/01/18', '02:16', 'Nupur', 'ki uske sath galat hua hai'),
#  ('22/01/18', '02:17', 'Vaibhav Tripathi', 'Glt to h hi'),
#  ('22/01/18',
#   '02:17',
#   'Vaibhav Tripathi',
#   'Pta nhi wo manai kaise kriti ko in the first place'),
#  ('22/01/18', '02:17', 'Nupur', 'arey kuch kuch karke'),
#  ('22/01/18', '02:17', 'Nupur', 'jhoot jhoot bolke'),
#  ('22/01/18', '02:18', 'Nupur', 'batayenge kabhi poora'),
#  ('22/01/18', '02:18', 'Nupur', 'abhi kriti ko pata chal gaya jhoot'),
#  ('22/01/18', '02:18', 'Nupur', 'toh wo thoda sa'),
#  ('22/01/18', '02:18', 'Nupur', 'hurt types hai'),
#  ('22/01/18',
#   '02:19',
#   'Nupur',
#   'still aaj jyoti ne usko jab sunaya na... toh itna pyar se aur sorry feel krke handle kiya'),
#  ('22/01/18',
#   '02:20',
#   'Nupur',
#   'uske bad bhi 10 bar explicitly jake jyoti ke room me usse bat kr rahi hai'),
#  ('22/01/18', '02:20', 'Vaibhav Tripathi', 'Shi ldki h be'),
#  ('22/01/18', '02:20', 'Nupur', 'ha yar'),
#  ('22/01/18',
#   '02:21',
#   'Vaibhav Tripathi',
#   'Lekin whi h ki zbrdsti tum kbtk kisi se care krwa loge'),
#  ('22/01/18', '02:22', 'Vaibhav Tripathi', 'Kriti bhi kuch hi time kr paegi'),
#  ('22/01/18', '02:22', 'Nupur', 'yar boht hi alag prani base hai yaha pe'),
#  ('22/01/18', '02:22', 'Nupur', '\xf0\x9f\x98\x91'),
#  ('22/01/18', '02:22', 'Nupur', 'extreme wale'),
#  ('22/01/18', '02:22', 'Nupur', 'sarla utkarsh mast maje lete hai'),
#  ('22/01/18', '02:23', 'Nupur', 'daily big boss hota hai'),
#  ('22/01/18', '02:23', 'Vaibhav Tripathi', 'Hehehe'),
#  ('22/01/18', '02:23', 'Vaibhav Tripathi', 'Hr kmre me bitching?'),
#  ('22/01/18', '02:24', 'Nupur', 'hehehe haa be'),
#  ('22/01/18', '02:24', 'Nupur', 'dher sare levels pe'),
#  ('22/01/18', '02:24', 'Nupur', 'different permutations combinations ke sath'),
#  ('22/01/18', '02:24', 'Nupur', '\xf0\x9f\x98\x9c'),
#  ('22/01/18',
#   '02:25',
#   'Vaibhav Tripathi',
#   'Hehe big boss me to least popular contestant ko nikal skte h at least. Tumhare pas to option nhi wo bhi'),
#  ('22/01/18', '02:25', 'Vaibhav Tripathi', '\xf0\x9f\x98\x9b'),
#  ('22/01/18', '02:26', 'Vaibhav Tripathi', 'Acha ye btao'),
#  ('22/01/18', '02:26', 'Vaibhav Tripathi', 'Uski to roomie a gyi'),
#  ...]

# %%
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import pandas as pd 

_words = ['delhi','mumbai']
stopwords = ['delhi']
# Generate wordcloud from chats.
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white',  
                min_font_size = 10).generate(_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-f97b3c0e48b8> in <module>()
#       8 wordcloud = WordCloud(width = 800, height = 800,
#       9                 background_color ='white',
# ---> 10                 min_font_size = 10).generate(_words)
#      11
#      12 # plot the WordCloud image
#
# /Users/vaibhavtripathi/anaconda/lib/python2.7/site-packages/wordcloud/wordcloud.pyc in generate(self, text)
#     603         self
#     604         """
# --> 605         return self.generate_from_text(text)
#     606
#     607     def _check_generated(self):
#
# /Users/vaibhavtripathi/anaconda/lib/python2.7/site-packages/wordcloud/wordcloud.pyc in generate_from_text(self, text)
#     584         self
#     585         """
# --> 586         words = self.process_text(text)
#     587         self.generate_from_frequencies(words)
#     588         return self
#
# /Users/vaibhavtripathi/anaconda/lib/python2.7/site-packages/wordcloud/wordcloud.pyc in process_text(self, text)
#     551         regexp = self.regexp if self.regexp is not None else r"\w[\w']+"
#     552
# --> 553         words = re.findall(regexp, text, flags)
#     554         # remove stopwords
#     555         words = [word for word in words if word.lower() not in stopwords]
#
# /Users/vaibhavtripathi/anaconda/lib/python2.7/re.pyc in findall(pattern, string, flags)
#     179
#     180     Empty matches are included in the result."""
# --> 181     return _compile(pattern, flags).findall(string)
#     182
#     183 if sys.hexversion >= 0x02020000:
#
# TypeError: expected string or buffer
